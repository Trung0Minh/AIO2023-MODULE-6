# %% [markdown]
# <a href="https://colab.research.google.com/github/Trung0Minh/AIO2023-MODULE-6/blob/main/rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis for Financial News

# %%
import torch
import torch.nn as nn

seed = 1
torch.manual_seed(seed)

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import nltk
# !pip install unidecode
import unidecode

nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
dataset_path = 'all-data.csv'
headers = ['sentiment', 'content']
df = pd.read_csv(
    dataset_path,
    names=headers,
    encoding='ISO-8859-1'
)
df
# Out:
#      sentiment                                            content
# 0      neutral  According to Gran , the company has no plans t...
# 1      neutral  Technopolis plans to develop in stages an area...
# 2     negative  The international electronic industry company ...
# 3     positive  With the new production plant the company woul...
# 4     positive  According to the company 's updated strategy f...
# ...        ...                                                ...
# 4841  negative  LONDON MarketWatch -- Share prices ended lower...
# 4842   neutral  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4843  negative  Operating profit fell to EUR 35.4 mn from EUR ...
# 4844  negative  Net sales of the Paper segment decreased to EU...
# 4845  negative  Sales in Finland decreased by 10.5 % in Januar...
#
# [4846 rows x 2 columns]

# %%
classes = {class_name: idx for idx, class_name in enumerate(df['sentiment'].unique())}
df['sentiment'] = df['sentiment'] .apply(lambda x: classes[x])
df
# Out:
#       sentiment                                            content
# 0             0  According to Gran , the company has no plans t...
# 1             0  Technopolis plans to develop in stages an area...
# 2             1  The international electronic industry company ...
# 3             2  With the new production plant the company woul...
# 4             2  According to the company 's updated strategy f...
# ...         ...                                                ...
# 4841          1  LONDON MarketWatch -- Share prices ended lower...
# 4842          0  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4843          1  Operating profit fell to EUR 35.4 mn from EUR ...
# 4844          1  Net sales of the Paper segment decreased to EU...
# 4845          1  Sales in Finland decreased by 10.5 % in Januar...
#
# [4846 rows x 2 columns]

# %%
classes
# Out:
# {'neutral': 0, 'negative': 1, 'positive': 2}

# %%
english_stopwords = stopwords.words('english')
stemmer = PorterStemmer()

# %%
len(english_stopwords)
# Out:
# 198

# %%
def text_normalize(text):
    text = text.lower()
    text = unidecode.unidecode(text)
    text = text.strip()
    text = re.sub(r'[^\w\s]', '', text)
    text = ' '.join([word for word in text.split() if word not in english_stopwords])
    text = ' '.join([stemmer.stem(word) for word in text.split()])
    return text

# %%
df['content'] = df['content'].apply(text_normalize)
df
# Out:
#       sentiment                                            content
# 0             0  accord gran compani plan move product russia a...
# 1             0  technopoli plan develop stage area less 100000...
# 2             1  intern electron industri compani elcoteq laid ...
# 3             2  new product plant compani would increas capac ...
# 4             2  accord compani updat strategi year 20092012 ba...
# ...         ...                                                ...
# 4841          1  london marketwatch share price end lower londo...
# 4842          0  rinkuskiai beer sale fell 65 per cent 416 mill...
# 4843          1  oper profit fell eur 354 mn eur 688 mn 2007 in...
# 4844          1  net sale paper segment decreas eur 2216 mn sec...
# 4845          1  sale finland decreas 105 januari sale outsid f...
#
# [4846 rows x 2 columns]

# %%
vocab = []
for sentence in df['content'].tolist():
    tokens = sentence.split()
    for token in tokens:
        if token not in vocab:
            vocab.append(token)

vocab.append('UNK')
vocab.append('PAD')
word_to_idx = {word: idx for idx, word in enumerate(vocab)}
vocab_size = len(vocab)
# Out:
# int

# %%
vocab[-2:]
# Out:
# ['UNK', 'PAD']

# %%
word_to_idx
# Out:
# {'accord': 0,
#  'gran': 1,
#  'compani': 2,
#  'plan': 3,
#  'move': 4,
#  'product': 5,
#  'russia': 6,
#  'although': 7,
#  'grow': 8,
#  'technopoli': 9,
#  'develop': 10,
#  'stage': 11,
#  'area': 12,
#  'less': 13,
#  '100000': 14,
#  'squar': 15,
#  'meter': 16,
#  'order': 17,
#  'host': 18,
#  'work': 19,
#  'comput': 20,
#  'technolog': 21,
#  'telecommun': 22,
#  'statement': 23,
#  'said': 24,
#  'intern': 25,
#  'electron': 26,
#  'industri': 27,
#  'elcoteq': 28,
#  'laid': 29,
#  'ten': 30,
#  'employe': 31,
#  'tallinn': 32,
#  'facil': 33,
#  'contrari': 34,
#  'earlier': 35,
#  'layoff': 36,
#  'contract': 37,
#  'rank': 38,
#  'offic': 39,
#  'worker': 40,
#  'daili': 41,
#  'postime': 42,
#  'report': 43,
#  'new': 44,
#  'plant': 45,
#  'would': 46,
#  'increas': 47,
#  'capac': 48,
#  'meet': 49,
#  'expect': 50,
#  'demand': 51,
#  'improv': 52,
#  'use': 53,
#  'raw': 54,
#  'materi': 55,
#  'therefor': 56,
#  'profit': 57,
#  'updat': 58,
#  'strategi': 59,
#  'year': 60,
#  '20092012': 61,
#  'baswar': 62,
#  'target': 63,
#  'longterm': 64,
#  'net': 65,
#  'sale': 66,
#  'growth': 67,
#  'rang': 68,
#  '20': 69,
#  '40': 70,
#  'oper': 71,
#  'margin': 72,
#  '10': 73,
#  'financ': 74,
#  'aspocomp': 75,
#  'aggress': 76,
#  'pursu': 77,
#  'increasingli': 78,
#  'focus': 79,
#  'hdi': 80,
#  'print': 81,
#  'circuit': 82,
#  'board': 83,
#  'pcb': 84,
#  'last': 85,
#  'quarter': 86,
#  '2010': 87,
#  'componenta': 88,
#  'doubl': 89,
#  'eur131m': 90,
#  'eur76m': 91,
#  'period': 92,
#  'zero': 93,
#  'pretax': 94,
#  'loss': 95,
#  'eur7m': 96,
#  'third': 97,
#  '52': 98,
#  'eur': 99,
#  '2055': 100,
#  'mn': 101,
#  '349': 102,
#  '235': 103,
#  'rose': 104,
#  '131': 105,
#  '87': 106,
#  'correspond': 107,
#  '2007': 108,
#  'repres': 109,
#  '77': 110,
#  'total': 111,
#  '211': 112,
#  '186': 113,
#  '97': 114,
#  'teliasonera': 115,
#  'tlsn': 116,
#  'offer': 117,
#  'line': 118,
#  'ownership': 119,
#  'core': 120,
#  'busi': 121,
#  'hold': 122,
#  'strengthen': 123,
#  'eesti': 124,
#  'telekom': 125,
#  'custom': 126,
#  'stora': 127,
#  'enso': 128,
#  'norsk': 129,
#  'skog': 130,
#  'mreal': 131,
#  'upmkymmen': 132,
#  'credit': 133,
#  'suiss': 134,
#  'first': 135,
#  'boston': 136,
#  'cfsb': 137,
#  'rais': 138,
#  'fair': 139,
#  'valu': 140,
#  'share': 141,
#  'four': 142,
#  'largest': 143,
#  'nordic': 144,
#  'forestri': 145,
#  'group': 146,
#  'purchas': 147,
#  'agreement': 148,
#  '7200': 149,
#  'ton': 150,
#  'gasolin': 151,
#  'deliveri': 152,
#  'hamina': 153,
#  'termin': 154,
#  'finland': 155,
#  'sign': 156,
#  'nest': 157,
#  'oil': 158,
#  'oyj': 159,
#  'averag': 160,
#  'platt': 161,
#  'index': 162,
#  'septemb': 163,
#  'plu': 164,
#  'eight': 165,
#  'us': 166,
#  'dollar': 167,
#  'per': 168,
#  'month': 169,
#  'finnish': 170,
#  'talentum': 171,
#  '205': 172,
#  '2005': 173,
#  '93': 174,
#  '2004': 175,
#  '1033': 176,
#  '964': 177,
#  'cloth': 178,
#  'retail': 179,
#  'chain': 180,
#  'seppaela': 181,
#  '8': 182,
#  '1552': 183,
#  '311': 184,
#  '171': 185,
#  'consolid': 186,
#  '16': 187,
#  'reach': 188,
#  'eur74': 189,
#  'amount': 190,
#  'eur0': 191,
#  '9': 192,
#  'compar': 193,
#  '7': 194,
#  'prior': 195,
#  'foundri': 196,
#  'divis': 197,
#  '631': 198,
#  '575': 199,
#  '2006': 200,
#  'machin': 201,
#  'shop': 202,
#  '164': 203,
#  '412': 204,
#  '354': 205,
#  'helsinki': 206,
#  'afx': 207,
#  'close': 208,
#  'higher': 209,
#  'led': 210,
#  'nokia': 211,
#  'announc': 212,
#  'team': 213,
#  'sanyo': 214,
#  'manufactur': 215,
#  '3g': 216,
#  'handset': 217,
#  'nokian': 218,
#  'tyre': 219,
#  'fourthquart': 220,
#  'earn': 221,
#  'beat': 222,
#  'analyst': 223,
#  'dealer': 224,
#  'incap': 225,
#  'servic': 226,
#  'pvt': 227,
#  'ltd': 228,
#  'subsidiari': 229,
#  'corpor': 230,
#  'revenu': 231,
#  '20072008': 232,
#  'director': 233,
#  'propos': 234,
#  'dividend': 235,
#  '12': 236,
#  '08': 237,
#  'paid': 238,
#  '2009': 239,
#  'lifetre': 240,
#  'found': 241,
#  '2000': 242,
#  'risen': 243,
#  'late': 244,
#  '30': 245,
#  'filippova': 246,
#  'trilater': 247,
#  'invest': 248,
#  'construct': 249,
#  'park': 250,
#  'st': 251,
#  'petersburg': 252,
#  'cours': 253,
#  'forum': 254,
#  'day': 255,
#  'russian': 256,
#  'economi': 257,
#  'open': 258,
#  'today': 259,
#  'megafon': 260,
#  'subscrib': 261,
#  'base': 262,
#  '161': 263,
#  '505': 264,
#  'million': 265,
#  'user': 266,
#  'decemb': 267,
#  '31': 268,
#  'market': 269,
#  'number': 270,
#  '24': 271,
#  '23': 272,
#  '2008': 273,
#  'estim': 274,
#  'incom': 275,
#  'life': 276,
#  'insur': 277,
#  '68': 278,
#  '32': 279,
#  'nonlif': 280,
#  '15': 281,
#  'eur193': 282,
#  '3': 283,
#  'eur179': 284,
#  '342': 285,
#  'eur43': 286,
#  '1': 287,
#  'eur1': 288,
#  'usd1': 289,
#  '4': 290,
#  'surg': 291,
#  '185': 292,
#  'eur167': 293,
#  'telest': 294,
#  'eur20': 295,
#  '122': 296,
#  'came': 297,
#  'acquisit': 298,
#  'made': 299,
#  'nordea': 300,
#  '18': 301,
#  'percent': 302,
#  'yearonyear': 303,
#  '364': 304,
#  'billion': 305,
#  'euro': 306,
#  '933': 307,
#  'ninemonth': 308,
#  'eur13': 309,
#  '6': 310,
#  'eur394': 311,
#  'eur3': 312,
#  'eur61': 313,
#  '5': 314,
#  'threemonth': 315,
#  '2': 316,
#  'brazilian': 317,
#  'unit': 318,
#  'secur': 319,
#  'solut': 320,
#  'provid': 321,
#  'fsecur': 322,
#  '1500': 323,
#  'client': 324,
#  'onlin': 325,
#  'news': 326,
#  'sourc': 327,
#  'resel': 328,
#  'web': 329,
#  'quot': 330,
#  'commerci': 331,
#  'vladimir': 332,
#  'brand_o': 333,
#  'say': 334,
#  '114': 335,
#  '822': 336,
#  '6865': 337,
#  '138': 338,
#  'lithuanian': 339,
#  'beer': 340,
#  '1441': 341,
#  'liter': 342,
#  'januari': 343,
#  'rise': 344,
#  'yearearli': 345,
#  'figur': 346,
#  'brewer': 347,
#  'associ': 348,
#  'cite': 349,
#  'result': 350,
#  'member': 351,
#  'vike': 352,
#  'cargo': 353,
#  '54': 354,
#  '2146': 355,
#  'volum': 356,
#  '70116': 357,
#  'properti': 358,
#  'portfolio': 359,
#  'kapite': 360,
#  '26862': 361,
#  '12597': 362,
#  'februari': 363,
#  '2011': 364,
#  'media': 365,
#  'sanoma': 366,
#  'hel': 367,
#  'saa1v': 368,
#  'yesterday': 369,
#  'almost': 370,
#  'tripl': 371,
#  'eur297': 372,
#  'eur107': 373,
#  'payout': 374,
#  'eliiv': 375,
#  'ep': 376,
#  '13': 377,
#  'aspo': 378,
#  'plc': 379,
#  'stock': 380,
#  'exchang': 381,
#  'releas': 382,
#  '11': 383,
#  'at8': 384,
#  '45': 385,
#  'esl': 386,
#  'ship': 387,
#  'part': 388,
#  'rautaruukki': 389,
#  'marin': 390,
#  'transport': 391,
#  'baltic': 392,
#  'sea': 393,
#  'commiss': 394,
#  '22': 395,
#  '44': 396,
#  'lend': 397,
#  '135': 398,
#  'traffic': 399,
#  'measur': 400,
#  'passeng': 401,
#  'kilometr': 402,
#  'rpk': 403,
#  'went': 404,
#  'avail': 405,
#  'seat': 406,
#  'ask': 407,
#  'januaryseptemb': 408,
#  'fiskar': 409,
#  '14': 410,
#  '654': 411,
#  '5253': 412,
#  '4877': 413,
#  '165': 414,
#  '140': 415,
#  '226': 416,
#  '152': 417,
#  'nyrstar': 418,
#  'also': 419,
#  'agre': 420,
#  'suppli': 421,
#  'talvivaara': 422,
#  '150000': 423,
#  'tonn': 424,
#  'sulphur': 425,
#  'acid': 426,
#  'annum': 427,
#  'leach': 428,
#  'process': 429,
#  'zinc': 430,
#  'concentr': 431,
#  'depart': 432,
#  'store': 433,
#  'hobbi': 434,
#  'hall': 435,
#  'seppala': 436,
#  'decreas': 437,
#  'export': 438,
#  'due': 439,
#  'rate': 440,
#  'partnership': 441,
#  'siemen': 442,
#  'network': 443,
#  'biohit': 444,
#  'healthcar': 445,
#  'ukbas': 446,
#  'public': 447,
#  'liquid': 448,
#  'handl': 449,
#  'diagnost': 450,
#  'test': 451,
#  'system': 452,
#  'alreadi': 453,
#  'carri': 454,
#  'lead': 455,
#  '1417': 456,
#  'book': 457,
#  'stood': 458,
#  'bln': 459,
#  '242': 460,
#  'pct': 461,
#  '365': 462,
#  'mln': 463,
#  '5343': 464,
#  'paper': 465,
#  'main': 466,
#  'includ': 467,
#  'price': 468,
#  'world': 469,
#  'second': 470,
#  'stainless': 471,
#  'steel': 472,
#  'maker': 473,
#  'dec': 474,
#  'euro603': 475,
#  '781': 476,
#  'euro3': 477,
#  '33': 478,
#  '431': 479,
#  'euro172': 480,
#  'euro0': 481,
#  '94': 482,
#  'previou': 483,
#  'within': 484,
#  'framework': 485,
#  'initi': 486,
#  'sitron': 487,
#  'jsc': 488,
#  'mikron': 489,
#  'microelectron': 490,
#  'compon': 491,
#  '02': 492,
#  'eur10': 493,
#  'eur6': 494,
#  'abroad': 495,
#  '62': 496,
#  'countri': 497,
#  'well': 498,
#  'ukrain': 499,
#  'standard': 500,
#  'charter': 501,
#  'stan': 502,
#  'ftse': 503,
#  '100': 504,
#  'royal': 505,
#  'bank': 506,
#  'scotland': 507,
#  'rb': 508,
#  'barclay': 509,
#  'barc': 510,
#  'bc': 511,
#  '17': 512,
#  'corp': 513,
#  'thursday': 514,
#  'cell': 515,
#  'phone': 516,
#  'thirdquart': 517,
#  'global': 518,
#  'financi': 519,
#  'publish': 520,
#  'friday': 521,
#  'seb': 522,
#  'soar': 523,
#  'sek6': 524,
#  '745': 525,
#  'bn': 526,
#  'sek1': 527,
#  '50': 528,
#  'meanwhil': 529,
#  'request': 530,
#  'alma': 531,
#  'newspap': 532,
#  'research': 533,
#  'manag': 534,
#  'jari': 535,
#  'kaivooja': 536,
#  'futur': 537,
#  'centr': 538,
#  'turku': 539,
#  'school': 540,
#  'econom': 541,
#  'drawn': 542,
#  'scenario': 543,
#  'nation': 544,
#  'model': 545,
#  'univers': 546,
#  'denver': 547,
#  'sweden': 548,
#  'gallerix': 549,
#  'accumul': 550,
#  'sek': 551,
#  'denomin': 552,
#  'support': 553,
#  'fast': 554,
#  'rout': 555,
#  'applic': 556,
#  'place': 557,
#  'atria': 558,
#  'expand': 559,
#  'moscow': 560,
#  'continu': 561,
#  'theagreement': 562,
#  'lemminkainen': 563,
#  'wherebi': 564,
#  'cramo': 565,
#  'acquir': 566,
#  'entir': 567,
#  'fleet': 568,
#  'oflemminkainen': 569,
#  'talo': 570,
#  'oy': 571,
#  'ita': 572,
#  'ja': 573,
#  'pohjoi': 574,
#  'suomo': 575,
#  'asimilar': 576,
#  'tatu': 577,
#  'hauhio': 578,
#  'ofcramo': 579,
#  'envisag': 580,
#  'three': 581,
#  'ferryboat': 582,
#  'option': 583,
#  'two': 584,
#  'confirm': 585,
#  '500': 586,
#  '6458': 587,
#  'june': 588,
#  'sold': 589,
#  'stake': 590,
#  'nordstjernan': 591,
#  'taken': 592,
#  'eqt': 593,
#  'remain': 594,
#  'kesko': 595,
#  '28022008': 596,
#  '0930': 597,
#  'capit': 598,
#  'kaukotelko': 599,
#  'wholli': 600,
#  'own': 601,
#  'sponda': 602,
#  '1545': 603,
#  'syndic': 604,
#  'oneyear': 605,
#  'juli': 606,
#  'subscript': 607,
#  'warrant': 608,
#  '119': 609,
#  '850': 610,
#  'program': 611,
#  'cover': 612,
#  'hdo': 613,
#  'platform': 614,
#  'ac800': 615,
#  'cxe880': 616,
#  'optic': 617,
#  'fttb': 618,
#  'node': 619,
#  'design': 620,
#  'forward': 621,
#  'return': 622,
#  'path': 623,
#  'transmiss': 624,
#  'electr': 625,
#  'gener': 626,
#  '350': 627,
#  'megawatt': 628,
#  'mw': 629,
#  'heat': 630,
#  'omx': 631,
#  '25': 632,
#  '092': 633,
#  '251867': 634,
#  'cap': 635,
#  '091': 636,
#  '471119': 637,
#  'car': 638,
#  'consider': 639,
#  'influenc': 640,
#  'tire': 641,
#  'maximum': 642,
#  '666104': 643,
#  'exercis': 644,
#  'b': 645,
#  'issu': 646,
#  '391630': 647,
#  '1566520': 648,
#  'real': 649,
#  'estat': 650,
#  'investor': 651,
#  'wednesday': 652,
#  'march': 653,
#  'dansk': 654,
#  'branch': 655,
#  '7year': 656,
#  'eur150m': 657,
#  'ilmarinen': 658,
#  'mutual': 659,
#  'pension': 660,
#  'eur50m': 661,
#  'estonia': 662,
#  '36': 663,
#  'fell': 664,
#  'synergi': 665,
#  'scale': 666,
#  'grimaldi': 667,
#  'personnel': 668,
#  'adjust': 669,
#  'divest': 670,
#  'redeliveri': 671,
#  'excess': 672,
#  'tonnag': 673,
#  'rinkuskiai': 674,
#  '181': 675,
#  '137': 676,
#  'kauno': 677,
#  'alu': 678,
#  'grew': 679,
#  '143': 680,
#  '960000': 681,
#  'telecomworldwire7': 682,
#  'april': 683,
#  '2006tj': 684,
#  'sell': 685,
#  'morn': 686,
#  'digit': 687,
#  'tj': 688,
#  'edita': 689,
#  '718430': 690,
#  'seri': 691,
#  'becom': 692,
#  'subject': 693,
#  'trade': 694,
#  'list': 695,
#  'togeth': 696,
#  'old': 697,
#  'fuel': 698,
#  'novemb': 699,
#  'tiimari': 700,
#  '194': 701,
#  'six': 702,
#  'turnov': 703,
#  '765': 704,
#  'focu': 705,
#  'supplier': 706,
#  'pipettor': 707,
#  'dispos': 708,
#  'tip': 709,
#  'vwr': 710,
#  'throughout': 711,
#  'europ': 712,
#  'combin': 713,
#  'enabl': 714,
#  'complex': 715,
#  'limit': 716,
#  'port': 717,
#  'connect': 718,
#  'get': 719,
#  'access': 720,
#  'wide': 721,
#  'mediterranean': 722,
#  'africa': 723,
#  'north': 724,
#  'america': 725,
#  'uwe': 726,
#  'bakosch': 727,
#  'blindspot': 728,
#  'come': 729,
#  'vantag': 730,
#  'point': 731,
#  'allow': 732,
#  'investig': 733,
#  'see': 734,
#  'whole': 735,
#  'stori': 736,
#  'high': 737,
#  'resolut': 738,
#  'unbroken': 739,
#  'video': 740,
#  'still': 741,
#  'slightli': 742,
#  'level': 743,
#  'ad': 744,
#  'predict': 745,
#  'poor': 746,
#  'trustworthi': 747,
#  'forecast': 748,
#  'current': 749,
#  'kemira': 750,
#  'posit': 751,
#  'metal': 752,
#  'coat': 753,
#  'finnlin': 754,
#  '5054': 755,
#  '4735': 756,
#  'chang': 757,
#  'structur': 758,
#  'optim': 759,
#  'effici': 760,
#  'julia': 761,
#  'prohaska': 762,
#  'commun': 763,
#  'physic': 764,
#  'infrastructur': 765,
#  'knowhow': 766,
#  'scienc': 767,
#  'sunris': 768,
#  'valley': 769,
#  'andriu': 770,
#  'bagdona': 771,
#  'broadband': 772,
#  'data': 773,
#  'tlt1v': 774,
#  'saw': 775,
#  'jump': 776,
#  'eur2': 777,
#  'eur995': 778,
#  '000': 779,
#  'aktia': 780,
#  '175': 781,
#  '82': 782,
#  '_land': 783,
#  '48': 784,
#  '64': 785,
#  '444': 786,
#  '373': 787,
#  'vaahto': 788,
#  '418': 789,
#  'account': 790,
#  '112': 791,
#  'food': 792,
#  'laennen': 793,
#  'tehtaat': 794,
#  '3491': 795,
#  '3096': 796,
#  'individu': 797,
#  'promot': 798,
#  'higherthanexpect': 799,
#  'mani': 800,
#  'genesi': 801,
#  'respect': 802,
#  'eur8': 803,
#  'circul': 804,
#  '70': 805,
#  '308': 806,
#  '1015': 807,
#  'annual': 808,
#  'swedish': 809,
#  'experienc': 810,
#  'howev': 811,
#  'favour': 812,
#  'trend': 813,
#  'cash': 814,
#  'flow': 815,
#  'activ': 816,
#  'eur121m': 817,
#  'eur97m': 818,
#  'lithuania': 819,
#  '190000': 820,
#  '70000': 821,
#  'fourth': 822,
#  '10507': 823,
#  '10270': 824,
#  '598': 825,
#  '12444': 826,
#  'kalmar': 827,
#  'espana': 828,
#  '113': 829,
#  '148': 830,
#  'x20ac': 831,
#  '402': 832,
#  '585u': 833,
#  '401': 834,
#  'eur655m': 835,
#  'eur438m': 836,
#  '255': 837,
#  'eur59': 838,
#  'charger': 839,
#  'deliv': 840,
#  '41': 841,
#  '659': 842,
#  'piec': 843,
#  '936': 844,
#  '932': 845,
#  'note': 846,
#  'declin': 847,
#  'though': 848,
#  'mobil': 849,
#  'yearago': 850,
#  '1451': 851,
#  '83': 852,
#  '34': 853,
#  '117': 854,
#  '5mn': 855,
#  '28': 856,
#  '245': 857,
#  '230': 858,
#  'ramir': 859,
#  'quarterend': 860,
#  '1287': 861,
#  '163': 862,
#  '33percent': 863,
#  '1246': 864,
#  'thesecond': 865,
#  '580': 866,
#  '743': 867,
#  '569': 868,
#  'ruukki': 869,
#  'aker': 870,
#  'norway': 871,
#  'suction': 872,
#  'anchor': 873,
#  'kalajoki': 874,
#  'show': 875,
#  'eur647m': 876,
#  'ceo': 877,
#  'sakari': 878,
#  'tamminen': 879,
#  'magazin': 880,
#  'gdp': 881,
#  'overal': 882,
#  'weekli': 883,
#  'basi': 884,
#  '40000': 885,
#  '50000': 886,
#  '1586': 887,
#  '414': 888,
#  'cent': 889,
#  '2803': 890,
#  'end': 891,
#  '2691': 892,
#  'ago': 893,
#  'best': 894,
#  'major': 895,
#  'breweri': 896,
#  'domest': 897,
#  '25688': 898,
#  'litr': 899,
#  '24592': 900,
#  'transact': 901,
#  'tecnomen': 902,
#  'workfors': 903,
#  'add': 904,
#  '269': 905,
#  '1058': 906,
#  '834': 907,
#  'rental': 908,
#  'latvian': 909,
#  'prioriti': 910,
#  'balanc': 911,
#  'sheet': 912,
#  'hannu': 913,
#  'krook': 914,
#  'yit': 915,
#  'build': 916,
#  'geograph': 917,
#  '21': 918,
#  'octob': 919,
#  'fish': 920,
#  'tackl': 921,
#  'rapala': 922,
#  'vmc': 923,
#  'rap1v': 924,
#  'eur18': 925,
#  'nine': 926,
#  'eur15': 927,
#  'bim': 928,
#  'inform': 929,
#  'softwar': 930,
#  'tekla': 931,
#  'modelbas': 932,
#  'adopt': 933,
#  'project': 934,
#  'abu': 935,
#  'dhabi': 936,
#  'metso': 937,
#  'miner': 938,
#  'gone': 939,
#  '19': 940,
#  'aldata': 941,
#  'gold': 942,
#  'french': 943,
#  '213': 944,
#  '61': 945,
#  '470': 946,
#  '66': 947,
#  'forest': 948,
#  'machineri': 949,
#  'ponss': 950,
#  '513': 951,
#  '375': 952,
#  'kci': 953,
#  'konecran': 954,
#  '35': 955,
#  'okmet': 956,
#  'silicon': 957,
#  'wafer': 958,
#  'semiconductor': 959,
#  'sensor': 960,
#  'norwegian': 961,
#  'solar': 962,
#  'norsun': 963,
#  'mono': 964,
#  'crystal': 965,
#  'pharmaceut': 966,
#  'orion': 967,
#  '190mn': 968,
#  '180mn': 969,
#  'babcock': 970,
#  'distribut': 971,
#  'harvest': 972,
#  'head': 973,
#  'south': 974,
#  'african': 975,
#  'sappi': 976,
#  'foreign': 977,
#  'graphic': 978,
#  'deputi': 979,
#  'md': 980,
#  'pekka': 981,
#  'silvennoinen': 982,
#  'aim': 983,
#  'next': 984,
#  'hkscan': 985,
#  'jaervisuomen': 986,
#  'portti': 987,
#  '80mn': 988,
#  '100mn': 989,
#  'advertis': 990,
#  '04': 991,
#  'takeov': 992,
#  'signific': 993,
#  'previous': 994,
#  'lemminkaeinen': 995,
#  '396': 996,
#  '42': 997,
#  'time': 998,
#  'h1': 999,
#  ...}

# %%
def transform(text, word_to_idx, max_seq_len):
    tokens = []
    for w in text.split():
        try:
            w_id = word_to_idx[w]
        except:
            w_id = word_to_idx['UNK']
        tokens.append(w_id)

    if len(tokens) < max_seq_len:
        tokens += [word_to_idx['PAD']] * (max_seq_len - len(tokens))
    elif len(tokens) > max_seq_len:
        tokens = tokens[:max_seq_len]
    return tokens

# %%
df['content'].tolist()
# Out:
# ['accord gran compani plan move product russia although compani grow',
#  'technopoli plan develop stage area less 100000 squar meter order host compani work comput technolog telecommun statement said',
#  'intern electron industri compani elcoteq laid ten employe tallinn facil contrari earlier layoff compani contract rank offic worker daili postime report',
#  'new product plant compani would increas capac meet expect increas demand would improv use raw materi therefor increas product profit',
#  'accord compani updat strategi year 20092012 baswar target longterm net sale growth rang 20 40 oper profit margin 10 20 net sale',
#  'financ aspocomp growth aspocomp aggress pursu growth strategi increasingli focus technolog demand hdi print circuit board pcb',
#  'last quarter 2010 componenta net sale doubl eur131m eur76m period year earlier move zero pretax profit pretax loss eur7m',
#  'third quarter 2010 net sale increas 52 eur 2055 mn oper profit 349 eur 235 mn',
#  'oper profit rose eur 131 mn eur 87 mn correspond period 2007 repres 77 net sale',
#  'oper profit total eur 211 mn eur 186 mn 2007 repres 97 net sale',
#  'teliasonera tlsn said offer line strategi increas ownership core busi hold would strengthen eesti telekom offer custom',
#  'stora enso norsk skog mreal upmkymmen credit suiss first boston cfsb rais fair valu share four largest nordic forestri group',
#  'purchas agreement 7200 ton gasolin deliveri hamina termin finland sign nest oil oyj averag platt index septemb plu eight us dollar per month',
#  'finnish talentum report oper profit increas eur 205 mn 2005 eur 93 mn 2004 net sale total eur 1033 mn eur 964 mn',
#  'cloth retail chain seppaela sale increas 8 eur 1552 mn oper profit rose eur 311 mn eur 171 mn 2004',
#  'consolid net sale increas 16 reach eur74 8 oper profit amount eur0 9 compar loss eur0 7 prior year period',
#  'foundri divis report sale increas 97 eur 631 mn eur 575 mn correspond period 2006 sale machin shop divis increas 164 eur 412 mn eur 354 mn correspond period 2006',
#  'helsinki afx share close higher led nokia announc plan team sanyo manufactur 3g handset nokian tyre fourthquart earn report beat analyst expect dealer said',
#  'incap contract manufactur servic pvt ltd subsidiari incap corpor finland plan doubl revenu 20072008',
#  'board director propos dividend eur0 12 per share 2010 eur0 08 per share paid 2009',
#  'lifetre found 2000 revenu risen averag 40 margin late 30',
#  'filippova trilater agreement invest construct technolog park st petersburg sign cours forum day russian economi open helsinki today',
#  'megafon subscrib base increas 161 2009 505 million user decemb 31 market share number custom amount 24 late 2009 23 late 2008 accord teliasonera estim',
#  'net incom life insur doubl eur 68 mn eur 32 mn net incom nonlif insur rose eur 52 mn eur 15 mn correspond period 2009',
#  'net sale increas eur193 3 eur179 9 pretax profit rose 342 eur43 1 eur1 usd1 4',
#  'net sale surg 185 eur167 8 telest said eur20 4 122 sale came acquisit made 2009',
#  'nordea group oper profit increas 2010 18 percent yearonyear 364 billion euro total revenu 3 percent 933 billion euro',
#  'oper profit ninemonth period increas eur13 6 net sale increas eur394 7 compar correspond period 2005',
#  'oper profit ninemonth period increas eur3 1 net sale increas eur61 5 compar correspond period 2007',
#  'oper profit threemonth period increas eur1 2 revenu increas eur20 2 compar correspond period 2005',
#  'brazilian unit finnish secur solut provid fsecur sign 1500 new client last year onlin news sourc resel web quot divis commerci director vladimir brand_o say',
#  'compani net profit rose 114 year 822 million euro 2005 sale 6865 million euro 138 year compani said earlier',
#  'lithuanian beer market made 1441 million liter januari rise 08 percent yearearli figur lithuanian brewer associ report cite result member',
#  'vike line cargo revenu increas 54 eur 2146 mn cargo volum increas 24 70116 cargo unit',
#  'fair valu properti portfolio doubl result kapite acquisit total eur 26862 12597 million',
#  '10 februari 2011 finnish media compani sanoma oyj hel saa1v said yesterday 2010 net profit almost tripl eur297 3 eur107 1 2009 announc propos rais payout',
#  'helsinki eliiv today report ep eur1 13 2009 increas ep eur1 12 2008',
#  'aspo plc stock exchang releas februari 11 2011 at8 45 esl ship ltd part aspo group sign new longterm contract rautaruukki corpor marin transport raw materi baltic sea',
#  'commiss incom increas 22 eur 44 mn lend volum rose 135',
#  'januari traffic measur revenu passeng kilometr rpk went 32 capac measur avail seat kilometr ask rose 122',
#  'januaryseptemb 2010 fiskar net profit went 14 yearonyear eur 654 million net sale eur 5253 million eur 4877 million',
#  'net incom life insur rose eur 165 mn eur 140 mn net incom nonlif insur eur 226 mn eur 152 mn 2009',
#  'nyrstar also agre suppli talvivaara 150000 tonn sulphur acid per annum use talvivaara leach process period suppli zinc concentr',
#  'sale depart store divis hobbi hall increas 7 sale cloth store subsidiari seppala decreas 4',
#  'sale risen export market',
#  'sale increas due grow market rate increas oper',
#  'agreement strengthen longterm partnership nokia siemen network',
#  'agreement sign biohit healthcar ltd ukbas subsidiari biohit oyj finnish public compani develop manufactur market liquid handl product diagnost test system',
#  'compani also estim alreadi carri invest lead increas net sale 2010 2009 reach eur 1417 million',
#  'compani order book stood 15 bln euro 22 bln septemb 30 2007 242 pct year intern order amount 365 mln euro 5343 mln',
#  'compani said paper demand increas main market includ public paper increas averag paper price 4 percent compar last year',
#  'world second largest stainless steel maker said net profit threemonth period dec 31 surg euro603 million us 781 million euro3 33 us 431 per share euro172 million euro0 94 per share previou year',
#  'within framework partnership nokia siemen network sign initi framework purchas agreement sitron subsidiari jsc mikron largest manufactur export microelectron compon russia',
#  'seppala revenu increas 02 eur10 1 finland revenu went 24 eur6 8 sale abroad rose 62 eur3 3 sale increas baltic countri well russia ukrain',
#  'share standard charter stan rose 12 ftse 100 royal bank scotland rb share rose 2 barclay share barc bc 17',
#  'share nokia corp rose thursday cell phone maker said thirdquart earn almost doubl share global handset market increas',
#  'financi report publish friday seb said net profit soar sek6 745 bn 2010 yearearli sek1 114 bn propos 50 dividend increas sek1 50 per share',
#  'sale depart store divis increas 15 sale cloth store subsidiari seppala increas 8 meanwhil sale hobbi hall decreas 12',
#  'request finnish media compani alma media newspap research manag jari kaivooja finland futur research centr turku school econom drawn futur scenario finland nation economi use model develop univers denver',
#  'sweden gallerix accumul sek denomin sale 1 eur denomin sale 11',
#  'compani support global custom develop new technolog offer fast rout product develop applic volum product',
#  'invest place atria plan expand moscow market',
#  'new agreement continu theagreement sign earlier year lemminkainen group wherebi cramo acquir entir construct machin fleet oflemminkainen talo oy ita ja pohjoi suomo sign asimilar agreement said tatu hauhio manag director ofcramo finland',
#  'first contract envisag construct three ferryboat option two unit confirm total valu 500 mln euro 6458 mln',
#  'june sold 30 percent stake nordstjernan invest group taken option acquir eqt remain share',
#  'kesko corpor stock exchang releas 28022008 0930 1 1 kesko corpor aspo plc today sign agreement aspo acquir share capit kaukotelko ltd subsidiari wholli own kesko',
#  'sponda plc stock exchang releas 5 decemb 2006 1545 eur 15 billion syndic credit facil sponda sponda sign agreement oneyear syndic credit facil total eur 15 billion',
#  'stock exchang announc 20 juli 2006 1 1 baswar share subscript warrant increas share capit total 119 850 share subscrib baswar warrant program',
#  'contract cover hdo platform ac800 cxe880 optic fttb node design increas forward return path capac transmiss network',
#  'new plant plan electr gener capac 350 megawatt mw heat gener capac',
#  'omx helsinki 25 index 092 pct 251867 helsinki cap portfolio index 091 pct higher 471119',
#  'sale growth car consider influenc tire market',
#  'maximum 666104 new share subscrib exercis b option 2004 stock option plan',
#  'result share issu number compani share increas 391630 share share capit total eur 1566520',
#  'finnish real estat investor sponda plc said wednesday 12 march sign agreement dansk bank helsinki branch 7year eur150m credit facil ilmarinen mutual pension insur compani 7year eur50m credit facil',
#  'rout helsinki finland tallinn estonia cargo volum increas 36 cargo volum finland sweden fell 9',
#  'measur includ increas synergi economi scale within grimaldi group personnel adjust divest redeliveri excess tonnag',
#  'rinkuskiai rais sale 181 percent 137 million liter sale kauno alu grew 143 percent 960000 liter',
#  'telecomworldwire7 april 2006tj group plc sell stake morn digit design oy finnish compani tj group plc said friday 7 april sign agreement sell share morn digit design oy edita oyj',
#  'telecomworldwire7 april 2006tj group plc sell stake morn digit design oy finnish compani tj group plc said friday 7 april sign agreement sell share morn digit design oy edita oyj',
#  '718430 new seri share becom subject trade helsinki stock exchang main list togeth old seri share juli 3 2006',
#  'fuel purchas contract sign three month deliveri septemb novemb',
#  'tiimari oper 194 store six countri includ core finnish market gener turnov 765 mln eur 2005',
#  'agreement biohit becom focu supplier pipettor dispos pipettor tip vwr custom throughout europ',
#  'combin servic enabl us offer complex strengthen servic chain limit baltic port connect also get access world wide grimaldi network mediterranean africa north america say uwe bakosch',
#  'blindspot come 1 vantag point allow investig see whole stori high resolut unbroken video',
#  'compani still expect turnov 2010 slightli increas level 2009 ad market predict still poor trustworthi forecast market develop contract manufactur busi current year',
#  'acquisit consider increas kemira sale market posit russian metal industri coat market',
#  'januaryseptemb 2007 finnlin net sale rose eur 5054 mn eur 4735 mn correspond period 2006',
#  'adjust chang group structur divis net sale increas 17',
#  'chang optim oper effici grow busi said julia prohaska director market commun fiskar',
#  'would invest physic infrastructur would also provid knowhow manag develop scienc technolog park said sunris valley director andriu bagdona',
#  '4 februari 2011 finnish broadband data commun system provid telest oyj hel tlt1v saw net profit jump eur2 1 last quarter 2010 eur995 000 period 2009',
#  'finnish aktia group oper profit rose eur 175 mn first quarter 2010 eur 82 mn first quarter 2009',
#  'finnish bank _land consolid net oper profit increas eur 48 mn first quarter 2005 eur 64 mn first quarter 2006',
#  'finnish financi group aktia report oper profit eur 444 mn januaryseptemb 2009 eur 373 mn correspond period 2008',
#  'finnish high technolog provid vaahto group report net sale eur 418 mn account period septemb 2007 februari 2008 increas 112 year earlier',
#  'net sale finnish food industri compani laennen tehtaat continu oper increas 13 2008 eur 3491 mn eur 3096 mn 2007',
#  'individu promot also gener slightli higherthanexpect revenu',
#  'biohit alreadi servic mani current genesi custom custom base expect expand result agreement',
#  'oper profit turnov threemonth period increas respect eur0 9 eur8 3 compar correspond period 2005',
#  'circul revenu increas 5 finland 4 sweden 2008',
#  'cloth chain seppaela net sale increas 70 eur 308 mn',
#  'construct volum meanwhil grow rate 1015 percent annual',
#  'finnish swedish construct market still experienc estim 4 annual growth 2008',
#  'howev biohit estim total net sale continu grow 2009 favour trend net sale lead profit 2009',
#  '2009 fiskar cash flow oper activ amount eur121m eur97m previou year',
#  'lithuania oper profit rose eur 190000 eur 70000 correspond period 2005',
#  'fourth quarter 2008 net sale increas 2 eur 10507 mn eur 10270 mn fourth quarter 2007',
#  'intern sale rose 598 eur 12444 mn',
#  'kalmar espana gener net sale 113 mln euro 148 mln 2005',
#  'net sale grew period x20ac 402 million 585u million x20ac 401 million 2006',
#  'net sale increas eur655m april june 2010 eur438m year earlier',
#  'net sale rose 255 yearonyear eur59 6 number charger deliv went 41 659 million piec',
#  'net sale total eur 936 mn eur 932 mn correspond period 2005',
#  'nokia also note averag sell price handset declin period though mobil phone profit margin rose 22 percent 13 percent yearago quarter',
#  'oper profit increas 1451 eur 83 mn eur 34 mn',
#  'oper profit margin increas 112 117',
#  'oper profit rose eur 311 mn eur 122 mn correspond period 2009',
#  'oper profit rose eur 5mn eur 28 mn fourth quarter 2008',
#  'oper profit eur 245 mn eur 230 mn',
#  'ramir net sale second quarterend june 30 euro 1287 million us 163 million 33percent increas compar euro 1246 million thesecond quarter last year',
#  'revenu grew 2 percent x20ac 580 million 743 million x20ac 569 million',
#  'ruukki announc sign agreement aker solut norway suppli 24 suction anchor septemb 2010 kalajoki unit finland',
#  'ruukki deliveri volum sell price show favour develop compani compar net sale grew 50 yearonyear eur647m ceo sakari tamminen said',
#  'sanoma magazin net sale estim grow 2006',
#  'bank forecast finland gdp grow 2 2010 2011',
#  'circuit overal product rate weekli basi excess averag 40000 tonn per day volum excess 50000 tonn per day reach individu day',
#  'compani consolid oper profit amount eur 1586 mn eur 414 mn yearonyear',
#  'depart store divis report increas sale 4 per cent',
#  'fair valu compani invest properti grew eur 2803 billion end march 2009 eur 2691 million year ago',
#  'last quarter best quarter 2009 net sale oper margin rose 122',
#  'major breweri increas domest beer sale 45 per cent last year 25688 million litr 24592 million litr 2004',
#  'transact doubl tecnomen workfors add fourth net sale',
#  'oper profit rose 269 eur 1058 834 million',
#  'purchas cramo becom second largest rental servic provid latvian market',
#  'prioriti 2009 strengthen compani balanc sheet increas cash flow ceo hannu krook said',
#  'purchas oper part yit strategi expand offer build system servic geograph',
#  '21 octob 2010 finnish fish tackl compani rapala vmc corp hel rap1v said today net profit rose eur18 9 first nine month 2010 eur15 1 period year earlier',
#  'structur bim build inform model softwar tekla modelbas softwar provid adopt construct manag deliveri univers project abu dhabi',
#  'accord finnish metso miner valu compani order gone eur 19 bn 12 month',
#  'finnish aldata solut sign contract suppli gold system two french retail chain',
#  'finnish bank _land report oper profit rose eur 213 mn second quarter 2009 eur 61 mn correspond period 2008',
#  'finnish financi group aktia oper profit 2009 increas eur 470 mn eur 66 mn 2008',
#  'finnish forest machineri manufactur ponss net sale grew eur 513 mn first quarter 2010 eur 375 mn correspond period 2009',
#  'finnish kci konecran rais net sale growth estim 2006 25 35',
#  'finnish okmet manufactur process silicon wafer semiconductor sensor industri norwegian solar wafer compani norsun sign contract okmet suppli norsun mono silicon crystal use solar cell manufactur',
#  'finnish pharmaceut compani orion net sale rose eur 190mn first quarter 2009 eur 180mn first quarter 2008',
#  'finnish ponss sign agreement babcock africa distribut support ponss forest machin harvest head inform system south africa',
#  'south african sappi becom largest foreign forest industri compani oper finland result acquisit finnish mreal corpor graphic paper busi unit',
#  'accord deputi md pekka silvennoinen aim doubl turnov next three year',
#  'accord hkscan finland plan increas jaervisuomen portti net sale eur 80mn eur 100mn',
#  'advertis circul revenu grew 34 04 respect',
#  'takeov cramo becom second largest rental servic provid latvian market',
#  'signific sale increas 186 russia',
#  'alma media expect net sale increas forecast previous',
#  'also lemminkaeinen profit account period went eur 31 mn eur 245 mn year ago',
#  'end march 2007 group order book eur 396 mn 42 correspond period 2006',
#  'time profit compani increas 10 h1 reach ls 79000',
#  'aviat system mainten base kansa gener net sale usd 26 million 2008',
#  'besid increas share meat variou sausag offer number new tast grill product shish kebab segment paavel said',
#  'oper profit net sale 12month period increas respect eur10 5 eur28 8 compar financi year 2004',
#  'oper profit net sale 12month period increas respect eur20 8 eur177 7 compar financi year 2004',
#  'oper profit net sale 12month period increas respect eur21 5 eur196 1 compar 2005',
#  'oper profit net sale 12month period increas respect eur4 7 eur26 7 compar 2004',
#  'oper profit net sale ninemonth period increas respect 266 34 compar correspond period 2006',
#  'oper profit net sale sixmonth period increas respect eur13 8 eur143 6 compar correspond period 2007',
#  'oper profit net sale sixmonth period increas respect eur0 4 eur3 2 compar correspond period 2005',
#  'oper profit net sale sixmonth period increas respect eur18 1 eur127 6 compar correspond period 2006',
#  'oper profit net sale sixmonth period increas respect eur7 5 eur655 5 compar correspond period 2005',
#  'oper profit net sale threemonth period increas respect eur15 1 eur131 5 compar correspond period 2005',
#  'oper profit net sale threemonth period increas respect eur16 0 eur139m compar correspond quarter 2006',
#  'oper profit sale threemonth period increas respect eur0 3 eur13 1 compar correspond period 2005',
#  'oper profit turnov ninemonth period increas respect eur2 4 eur43 8 compar correspond period year ago',
#  'oper profit turnov sixmonth period increas respect eur17 6 eur1149 9 compar correspond period 2007',
#  'oper profit turnov sixmonth period increas respect eur0 1 eur29 0 compar correspond period year ago',
#  'cargo volum grew 7',
#  'cargo volum increas approxim 5',
#  'compar oper profit total eur 854mn eur 730mn 2004',
#  'digia said consolid net sale januaryjun 2010 eur67 8 97 period 2009 eur61 9',
#  'dilut earn per share ep rose eur 029 eur 005',
#  'dilut earn per share ep rose eur 052 versu eur 009',
#  'dilut earn per share ep rose eur 105 eur 064',
#  'dilut earn per share ep rose eur 368 eur 050',
#  'dilut ep rose eur3 68 eur0 50',
#  'ebit margin 14 51',
#  'editor note grimaldi gener 17 bln euro 2182 bln turnov 2005 ansa report may 29 2006',
#  'ep quarter eur0 00 compar eur0 01 third quarter 2008 repres group net sale third quarter eur15 3 28 compar eur14 9 third quarter 2008',
#  'ep continu oper came 030 eur 017',
#  'equiti ratio 609 compar 542 third quarter 2007 net sale frozen food busi total eur 110 5 third quarter 2006',
#  'eur928 000 q1 2010 6 may 2010 finnish textil cloth design compani marimekko oyj hel mmo1v said today net profit rose eur928 000 first quarter 2010 eur13 000 correspond period year earlier',
#  'finlandbas elcoteq se privat held provid electron manufactur servic commun compani said thursday sign longterm manufactur suppli deal commun equip compani andrew corp',
#  'finnish cutleri hand tool maker fiskar oyj abp hel fisa said today net profit rose eur 241 million usd 336 third quarter 2010 eur 179 million year earlier',
#  'finnish depart store chain stockmann oyj abp net profit rose 398 mln euro 568 mln first nine month 2007 374 mln euro 534 mln period 2006',
#  'finnish lift equip maker konecran oyj said juli 30 2008 net profit rose 712 mln euro 1111 mln first half 2008 571 mln euro 891 mln period 2007',
#  'finnish messag solut develop tecnomen corpor omx helsinki tem1v said thursday 11 decemb receiv expans order converg charg solut latin america',
#  'finnish metal industri solut supplier outotec oyj net profit rose 504 mln euro 725 mln first nine month 2007 201 mln euro 289 mln period 2006',
#  'finnish metal product compani componenta oyj net profit rose 261 mln euro 359 mln first quarter 2007 53 mln euro 73 mln period 2006',
#  'finnish offic suppli comput accessori dealer belttongroup plc said net profit rose 13 mln euro 17 mln 2006 113 mln euro 15 mln 2005',
#  'finnish secur privaci softwar solut develop stonesoft oyj said januari 7 2008 preliminari sale stoneg product grew 59 pct yearonyear 36 mln euro 53 mln fourth quarter 2007',
#  'finnish silicon wafer technolog compani okmet oyj omx helsinki okm1v report thursday 7 august oper profit eur5 3 period januaryjun 2008 eur3 3 correspond period 2007',
#  'finnish softwar develop done solut oyj said net profit increas 35 mln euro 46 mln 2006 23 mln euro 30 mln 2005',
#  'first quarter underli oper profit rose 41 mln eur 33 mln year earlier',
#  'follow acquisit relacom strengthen presenc finland serv oper offic market mobil fix network construct instal mainten servic',
#  'first nine month 2010 compani net profit rose eur41m eur30m correspond period 2009',
#  'helsinki afx retail wholesal group kesko report net sale 6594 mln eur februari increas 108 pct yearonyear',
#  'howev net sale 2010 seen grown eur598 3 eur582 3 2009',
#  'howev sale return growth apriljun 2010 ceo pekka eloholma said',
#  'raguti control finnish breweri report 54percent rise beer sale 1044 million litr held 1109percent market share',
#  'svyturysuteno alu control nordic group baltic beverag hold bbh post 47percent growth beer sale januarymay 4622 million litr',
#  '2007 contempu gener revenu nok 693 approx',
#  'addit kone sign twoyear mainten contract escal',
#  'decemb alon member lithuanian brewer associ sold total 203 million liter beer increas 19 percent sale 1992 million liter decemb 2004',
#  'januaryseptemb 2009 group net interest incom increas eur 1124 mn eur 743 mn januaryseptemb 2008',
#  'q1 2010 bank _land net interest incom increas eur 91 mn eur 97 mn',
#  'sweden oper profit period review total eur 34 mn 308 correspond period 2005',
#  'fourth quarter 2009 orion net profit went 338 yearonyear eur33m',
#  'second quarter 2010 group net profit rose eur 31 million eur 25 million apriljun 2009',
#  'second quarter 2010 group net profit rose eur3 1 eur2 5 apriljun 2009',
#  'third quarter net sale increas 12 yearonyear eur 1595 million 6 compar currenc rate growth',
#  'third quarter net sale increas 12 yearonyear eur159 5 6 compar currenc rate growth',
#  'incap estim gener revenu 10 mln euro 132 mln indian oper 2007',
#  'market share widen 4851 percent 4831 percent year earlier',
#  'total annual revenu come 160 mln zloti 569 mln42 3 mln euro',
#  'kesko agro eesti retail wholesal grain agricultur wareh machineri accessori net sale 81 million euro 2007 increas onetenth preced year',
#  'kesko car import retail busi vvauto saw sale grow 171 pct',
#  'kone net sale rose 14 yearonyear first nine month 2008',
#  'adp news feb 11 2009 finnish manag softwar solut provid ixono oyj hel xns1v said today net profit rose eur 35 million usd 45 2008 eur 31 million 2007',
#  'adp news feb 12 2009 finnish solut provid affecto oyj hel afe1v said today net profit rose eur 85 million usd 11m 2008 eur 7 million 2007',
#  'adp news feb 6 2009 finnish fish tackl compani rapala vmc corp hel rap1v said today net profit rose eur 192 million usd 246 2008 eur 175 million 2007',
#  'adp news nov 5 2008 finnish electron measur product solut maker vaisala oyj omx vaia said today net profit rose eur 18 million usd 231 first nine month 2008 eur 1',
#  'adp news oct 29 2008 finnish lift equip maker konecran oyj omx kcr1v said today net profit rose eur 1166 million usd 1491 first nine month 2008 eur 736 million',
#  'metso expect net sale increas 10 2008 compar exchang rate',
#  'mreal gener turnov eur5 6 bn 2006 15500 employe',
#  'nest oil corp sign longterm procur contract honkajoki oy findest protein oy own finnish food manufactur suppli anim fat biodiesel product nest 200000 bcd porvoo finland refineri',
#  'net interest incom increas 45 eur 314 mn eur 300 mn 2004',
#  'net interest incom eur 1522 mn eur 1010 mn 2008',
#  'net interest incom eur 393 mn eur 327 mn',
#  'net sale veget oil busi rose eur 106 mn eur 101 mn',
#  'nokia multimedia net sale total eur 57 bn 45 correspond period 2005',
#  'oper incom rose eur 6964 mn eur 6003 mn 2009',
#  'oper profit kauppalehti group rose eur 15 mn eur 13 mn marketplac eur 13 mn eur 10 mn third quarter 2006',
#  'oper profit rose eur 194 mn eur 245 mn',
#  'oper profit rose 221 mln eur 199 mln',
#  'oper profit rose eur 16 mn eur 11 mn correspond period 2006',
#  'oper profit rose eur 1034 mn eur 232 correspond period 2006',
#  'oper profit rose eur 135 mn eur 97 mn correspond period 2006',
#  'oper profit rose eur 267 mn eur 149 mn correspond period 2006',
#  'oper profit rose eur 278 mn eur 175 mn 2008',
#  'oper profit rose eur 32 mn eur 10 mn correspond period 2008',
#  'oper profit rose eur 47 mn eur 36 mn',
#  'oper profit rose eur 47 mn eur 46 mn',
#  'oper profit rose eur 92 mn eur 68 mn correspond period 2007',
#  'oper profit rose eur2 4 eur1 6 year earlier',
#  'oper profit surg eur21m eur106 000',
#  'oper profit total eur 377 mn slightli eur 372 mn correspond period 2006',
#  'oper profit total eur 55 mn eur 07 mn',
#  'oper profit eur 114 mn eur 75 mn',
#  'oper profit eur 1397 mn 23 eur 1138 mn',
#  'order intak grew 40 yearonyear 30 yearonyear respect eur 576 million eur 17 billion respect januaryseptemb julyseptemb 2010 period',
#  'order receiv grew 55 yearonyear eur732m',
#  'orion pharma oper profit increas 425 2004',
#  'passeng volum rose 84 account period',
#  'passengerrel revenu rose 51 eur 4608 mn eur 4385 mn 2009',
#  'press releas 9 octob 2009 ruukki sign contract deliv instal steel structur bridg kyronsalmi strait savonlinna finland',
#  'pretax profit rose eur 06 mn eur 04 mn correspond period 2005',
#  'pretax profit rose eur 1019 mn eur 1007 correspond period 2005',
#  'pretax profit rose eur 178 mn eur 149 mn 2005',
#  'pretax profit total eur 3974 mn eur 1647 mn',
#  'previous compani guid ebit sale growth 20 pct 10 pct respect year',
#  'previous compani estim oper profit reach level 2005',
#  'profit period total eur 394 mn eur 339 mn correspond period 2006',
#  'profit period eur 59 mn eur 13 mn',
#  'profit period eur 98 mn eur 60 mn 2004',
#  'revenu grew 12 percent x20ac 36 billion us 45 billion',
#  'revenu juli septemb grew 14 percent euro 467 million year earlier compani said thursday',
#  'revenu time grew 14 percent 43 million euro',
#  'ruukki sign contract deliv instal steel structur bridg kyronsalmi strait savonlinna finland',
#  'sale latin america increas 42 eur 432mn total 87 mn mobil devic sold area repres increas 32 correspond period 2009',
#  'sale cloth develop best',
#  'sanoma magazin finland net sale grew eur 1401 mn eur 1318 mn',
#  'satama net profit third quarter 2007 rose 275000 euro 395000 270000 euro 388000 period 2006',
#  'section region news demand finnair asian traffic measur passeng kilomet 349 august compar last year',
#  'svyturysuteno alu control nordic group baltic beverag hold bbh post 61 percent growth beer sale januaryseptemb 10199 million liter',
#  'would increas estim sale 117 million last year',
#  'agreement expand tekla structur scope use bridg design',
#  'aim increas sale least one fifth 2006',
#  'chain post sale 298 million euro full 2005 rise 195 percent yearonyear',
#  'compani expect net sale 2008 increas 510 2007',
#  'compani expect net sale first half 2008 reach previou year level',
#  'compani process build new fleet place order 10 pmax tanker 65200 dwt',
#  'compani oper incom ebit total eur 00 mn eur 03 mn yearonyear',
#  'ep outlook increas 56 pct 2007 70 pct 2008',
#  'fair valu invest properti total eur 25349 mn eur 24551 mn 2006',
#  'finnish govern announc wednesday sold 32 percent stake chemic fertil group kemira oyj x20ac 6556 million 890u million send compani share price 6 percent',
#  'firm gener sale 187 mln eur 2005',
#  'german compani also sign code share agreement anoth oneworld member american airlin inc part usbas amr corp nyse amr',
#  'helsinkibas compani also own salomon atom suunto brand said net profit rose 15 percent three month dec 31 x20ac 47 million 61u million x20ac 408 million year earlier',
#  'increas capit stock regist finnish trade regist 20 novemb 2006',
#  'oper profit grain trade increas eur 20 mn eur 14 mn 2005',
#  'stock rose second day wednesday bring twoday rise gbx12 0 20',
#  'stock rose third day tuesday bring threeday rise gbx10 50 18',
#  'transact line aspo strategi expand baltic sea region eastern market',
#  'transact would increas earn per share first quarter eur0 28',
#  'recoveri base metal price increas demand metal china howev',
#  'new represent extend comptel global presenc total 18 countri serv 250 custom 80 countri worldwid',
#  'tietoen use nokia intellisync mobil suit wireless email calendar devic manag capabl compani extend servic custom',
#  'total oper revenu grew 276 yearonyear eur61m',
#  'vacon cash flow oper grew eur 371 mn eur 219 mn year ago',
#  'vacon suppli drive ruselprom power rang 200 kw 2 mw',
#  'also strengthen exist partnership cybercom say telest cto esko myllyla',
#  'via satlan acquisit telest plan expand market presenc video servic partner cabl oper broadcast iptv servic provid',
#  'acquisit compani expand offer north central south america said',
#  'extens new contract eight engin plant produc 100 mw said',
#  'yit say acquisit part strategi expans central eastern european market',
#  'baswar product sale grew strongli financi period 24 percent',
#  'second quarter 2010 firstquart growth net sale sinc third quarter of2008 said magnu rosen ramir ceo',
#  'transact strengthen posit design brand good said fiskar presid ceo heikki allonen point two group rel overlap oper',
#  '1 februari 2011 finnish textil cloth compani marimekko oyj hel mmo1v said today preliminari oper profit grew eur8 2 2010 eur6 3 2009',
#  'finnish componenta publish new longterm strategi period 20112015 aim grow togeth custom',
#  'finnish larox sign contract talvivaara project deliveri filter talvivaara nickel mine sotkamo finland',
#  'affecto expect net sale whole 2010 increas 2009 level reach eur 103 million',
#  'cash flow oper rose eur 527 mn eur 156 mn 2007',
#  'commiss incom rose 257 eur 161 mn eur 128 mn 2004',
#  'componenta object agreement increas busi exist product line',
#  'earn per share januaryjun 2010 eur0 30 increas 20 yearonyear eur0 25',
#  'earn per share ep rose eur 011 eur 003',
#  'elisa said mobil subscript grew 7 percent 2007 mainli custom adopt socal third gener mobil technolog',
#  'ep quarter came 036 eur 033 eur year ago ahead forecast 033 eur',
#  'ep grew 004 eur 002 eur',
#  'export grew 165 percent 191 million liter',
#  'finnish invest group panostaja oyj said net profit went 86 mln euro 114 mln fiscal 200506 end octob 31 2006 28 mln euro 37 mln period fiscal 200405',
#  'finnish metal compon supplier componenta oyj said net profit went 35 mln euro 45 mln 2006 22 mln euro 28 mln 2005',
#  'finnish silicon wafer technolog compani okmet oyj omx helsinki okm1v report thursday 30 octob oper profit eur7 4 januaryseptemb 2008 eur6 1 correspond period 2007',
#  'fiskar brand report net sale eur 1458 mn eur 1384 mn',
#  'geosentr oyj geosolut busi unit gypsii mobil digit lifestyl applic geomobl social network platform sign agreement nanj mynet make gypsii mobil social network platform avail custom china mobil',
#  'helsinki afx outokumpu technolog said sign 35 mln eur agreement mongolia erdenet mine corpor engin first hydrocopp plant built erdenet mine site',
#  'howev proport paid stand order grew 2009',
#  'addit demand finland export line stone product also increas',
#  'januaryseptemb 2007 group net sale continu oper rose eur 2131 mn eur 1726 mn correspond period 2006',
#  'julyseptemb 2008 yit net sale increas eur 9708 mn compar eur 9068 mn correspond period 2007',
#  'report period net sale rose 8 yearonyear eur64 3 due busi acquisit realiz first half 200809 effect eur10 9 review period',
#  'report period compani oper profit grew 432 eur 6 million',
#  'last year net sale rose eur 683 million eur 622 million',
#  'last year compani rais turnov approxim 7 million lita eur 2 mln 61 million lita 2004',
#  'adp news nov 18 2008 finnish ac drive manufactur vacon oyj omx vac1v said today set new repres offic romania ukrain serv grow market eastern southeastern europ',
#  'marimekko group fullyear net sale estim increas 10',
#  'net sale surg 30 eur 36 million',
#  'net sale went 1 yearonyear eur 29 million affect busi acquisit realiz previou financi period effect eur 51 million review period',
#  'nevertheless market share rose 4914 percent 4851 percent year earlier',
#  'nokia world largest mobil phone manufactur china postel china largest mobil phone distributor longstand partnership continu grow stronger time',
#  'octoberdecemb sale 302 mln eur 253 pct increas year year',
#  'olvi control 94 percent stake raguti le coq said annual report publish earlier year lithuanian breweri sale reach 1504 million euro last year rise 204 percent 1249 million euro 2004',
#  'olvi expect sale market share increas first quarter 2010',
#  'olvi target strengthen market share soft drink miner water cider long drink energi drink',
#  'oper profit increas eur 140 mn eur 49 mn correspond period 2005',
#  'oper profit asian plant grew markedli',
#  'oper profit total eur 825mn eur 763mn 2004',
#  'oper profit total eur 830 mn eur 235 mn yearonyear',
#  'product capac increas 36 000 85 000 tonn per year raw materi continu recycl paper board',
#  'profit period increas eur 29 mn eur 105 mn',
#  'profit per share eur 103 eur 087',
#  'return capit employ rose 48 percentag point 196',
#  'revenu juli septemb grew 21 percent euro 23 billion finnish compani said thursday',
#  'revenu grew 1 percent euro742 2 million us 964 million euro735 million',
#  'ruukki order book end 2010 30 yearonyear 10 quarteronquart',
#  'ruukki sign contract norwegian compani veidekk entreprenor',
#  'sale finland rose 39 intern growth 07',
#  'sale secur system packag increas slightli',
#  'stora enso thirdquart pretax profit doubl eur 197mn',
#  'strongest growth seen new market russia czech republ slovakia',
#  'airlin order nine airbu a350900 aircraft deliveri 2011 becom lead airlin latest variant rollsroyc trent seri engin call 1700',
#  'compani intensifi smelter oper increas annual product capac 230000 tonn copper',
#  'compani market share continu increas',
#  'compani schedul traffic measur revenu passeng kilometr rpk grew 2 nearli 3 passeng carri schedul flight februari 2009',
#  'compani said invest new market area result sale increas sweden poland russia lithuania',
#  'dispos autotank also strengthen aspo capit structur comment gustav nyberg ceo aspo',
#  'earn per share quarter came 025 eur 020 eur quarter year earlier',
#  'econom occup rate sponda properti portfolio rose 912 888 2006',
#  'finnish supplier bssoss va telecom oper tecnotre receiv expans order worth total us 73 mn converg charg next gener messag solut latin america compani announc without specifi oper place order',
#  'group 12month oper profit grew 31 percent 3378 million euro',
#  'growth activ talentum custom start end 2009 continu report period compani state',
#  'growth net sale first half 2008 28 compar first half 2007',
#  'pretax profit group life insur busi increas eur 36 million eur 27 million',
#  'pretax profit group life insur busi increas eur36m eur27m',
#  'total deliveri volum paper busi 2010 1155000 tonn 1132000 tonn 2009',
#  'valu firm forestri hold increas sek 36 bn',
#  'new deal strengthen partnership telemig celular tecnomen start sinc begin telemig prepaid oper',
#  'turnov rose eur21m eur17m',
#  'xerox stora enso team tailor igen3 shortrun ondemand packag market',
#  'yit construct town riihimaeki sign leas contract wherebi town occupi travel centr offic facil',
#  'upgrad intend rais network capac 450 mhz 630 mhz sever citi enabl bidirect servic digit televis well broadband data',
#  'finnish compani stockmann sign contract compani technopoli',
#  'accord notic skandinaviska enskilda banken ab publ helsinki branch 10 august 2009 divest total 11958000 alma media share ilkkayhtyma oyj kaleva kustannu oy condit agreement made compani 1 juli 2009 fulfil',
#  'previous announc geosentr oyj enter financ agreement lead investor june 30 2010 enabl compani receiv financ aggreg amount 6m',
#  'time market autom liquid handl devic alreadi larger pipett accord biohit',
#  'efor ceo reijo maihaniemi said compani develop alreadi deliv power suppli unit respect system base technolog chines sector compani zte corp 000063',
#  'finnish talvivaara mine co hel tlv1v said thursday pick bofa merril lynch jpmorgan nyse jpm joint bookrunn plan issu convert note worth eur250m usd332m',
#  'lead product turn increas 60000 tonn 2009 would twofold increas current capac level zahariev said',
#  'lemminkainen oyj said sign credit agreement nordea bank sto nda pohjola bank hel poh1 sampo bank hel sama svenska handelsbanken sto shb',
#  'pohjola could increas stake 45 2013',
#  'scandic feed also diversifi tosno product portfolio',
#  'separ yit corpor austrian firm e ag last week sign agreement sale e build system servic busi germani austria poland czech republ hungari romania eur 55 mln',
#  'agreement jm one seri contract teliasonera sign recent month residenti construct real estat manag compani sweden',
#  'compani intend rais product capac 2006',
#  'estim valu contract eur12 4 vaisala headquart helsinki finland develop manufactur electron measur system meteorolog environment scienc traffic industri',
#  'mall part baltic pearl develop project citi st petersburg baltic pearl cjsc subsidiari shanghai foreign joint invest compani develop home 35000 peopl',
#  'new facil known technopoli pulkovo introduc russian market entir new concept creat oper grow commerciallyfund scienc technolog park support growth knowledgeintens compani',
#  'therebi compani expand offer north central south america',
#  'member partner use mostli appar increas effici result servic observ perttu puro tradeka',
#  'vacon control 5 compani via invest fund power fund eur 10 usd 1397',
#  'order includ wartsila order book second quarter compani ad',
#  'manag decid end 2005 increas cathod copper capac',
#  '4 complet name sharehold otto henrik bernhard nyberg 5 inform amount share transfer correspond 568 total number share aspo plc',
#  'data process unit collect data calcul rvr valu provid data user via variou interfac',
#  'tinyurl link take user scam site promis user earn thousand dollar becom googl nasdaq goog cash advertis',
#  'alexandria va march 28 pertti salmi hanna vuolteenaho oulu finland sami viitasaari ii finland develop ornament design handset us patent trademark offic announc',
#  'alexandria va oct 3 markka oksanen harald kaaja helsinki finland juha salokannel kangasala finland arto palin viiala finland develop system provid commun secur',
#  'earlier report nokian tyre build plant town vsevolozhsk russia leningrad region annual product capac 4 million tire',
#  'biohit inc expand mline famili pipettor addit new 110 ml volum rang',
#  'capman finnish altern asset manag made acquisit helsinkifocus vehicl real estat fund fund bought sevenstori offic built 1973 underw refurbish end 1990',
#  'compar ftse 100 index rose 367 point 06 day rel price chang 02',
#  'compar ftse 100 index rose 515 point 09 day rel price chang 06',
#  'compar ftse 100 index rose 949 point 16 day rel price chang 04',
#  'deliveri start later 2010 volum increas year 20112012',
#  'finland nokian tyre kazakhstan ordabasi corpor sign agreement build plant astana produc car tire ordabasi chairman dinmukhamet idrisov said press confer',
#  'finnish busi softwar group affectogenimap oyj said sign agreement acquir share swedish sector compani intellibi ab 12 mln euro 158 mln debtfre basi',
#  'finnish heatretain fireplac maker tulikivi oyj said august 29 2007 local tile stove util ceram subsidiari kermansavi oy merg tulikivi mean absorpt order streamlin latest corpor structur',
#  'finnish silicon wafer manufactur okmet oyj said june 29 2007 sign agreement nordea bank finland plc local subsidiari swedish commerci bank nordea bank ab refin okmet syndic bank facil amount 20 mln euro 269 mln',
#  'furthermor bung also sign licens agreement sunnuntai carlshamn mejeri brand',
#  'german commerzbank ag hamburg branch us jp morgan nyse jpm particip arrang dutch ing am inga coarrang',
#  'april 2005 nest separ parent compani finnish energi compani fortum becam list helsinki stock exchang',
#  'russia raisio food divis home market stretch way vladivostok',
#  'septemb 2010 finnish group agre buy danish compani rose poultri eur23 9 combin cash stock',
#  'increas number share base option right grant manag compani stock option plan 2006',
#  'plan expand product portfolio harbor segment chief execut pekka lundmark told financi time deutschland',
#  '30 offic worldwid 90 pct net sale gener outsid finland',
#  'has80 branch finland annual revenu finland',
#  'kaukotelko ltd press releas 19062007 1400 1 1 telko group kaukotelko expand strateg partnership bp industri lubric servic bp il acquir total ownership bp swedish retail compani moluballoy ab',
#  'milan afx italian ship group grimaldi increas stake finnish compani finnlin 354 pct 305 pct held june accord news agenc ansa',
#  'nokia messag 11 enabl custom receiv email 10 email account mobil phone support pop imap email servic',
#  'product capac rise gradual 170000 tonn 215000 tonn',
#  'ramir danish subsidiari ramir today sign agreement acquir busi asset machineri rental compani jydsk materiel udlejn locat west jutland',
#  'share repurchas 11012008 helsinki stock exchang behalf sampo plc dansk bank helsinki branch',
#  'solidium pick tikkurila share dividend book valu eur15 80 per share',
#  'takoma carri transact acquir entir share capit moventa parkano oy run factori parkano southern finland',
#  'agreement provid switch doubl convert capac whilst open manufactur locat china',
#  'build owner develop sun hung kai properti group one largest properti compani hong kong develop type premium residenti commerci project sale invest',
#  'compani aim final negoti sign contract start octob 2008',
#  'compani sign letter intent sale 17 septemb 2010 envisag seal actual agreement 1 januari 2011',
#  'compani also said novemb 16 2006 real estat fund ky sign agreement finnish window maker fenestra oy build window plant forssa southern finland',
#  'compani commit expand apollo portfolio',
#  'contract sign yesterday run five year includ twoyear extens option',
#  'contract cover instal train startup servic',
#  'contract valu amount eur11m compani ad',
#  'contract sign acquir uranium produc sotkamo nickelzinc mine eastern finland own talvivaara',
#  'expand agreement cover sale market distribut benefon navig locat devic china',
#  'omx nordic 40 omxn40 index compris 40 trade nordic stock nasdaq omx exchang close 043 113884 point wednesday',
#  'omx nordic 40 omxn40 index compris 40 trade nordic stock nasdaq omx exchang close 129 108447 point friday',
#  'tietoen sign agreement acquir indian research develop rd servic provid turnkey softwar solut develop fortuna technolog pvt ltd 21 mln euro 303 mln septemb 2007',
#  'number one mean creat ad valu stakehold everyth',
#  'term offtak agreement talvivaara cameco provid upfront invest maximum 60 million cover construct cost uranium extract circuit',
#  'vaisala oyj press releas septemb 30 2010 vaisala sign contract sell oxygen measur technolog busi sick maihak gmbh',
#  'beij xfnasia hong konglist standard charter bank said sign china mobil phone dealer financ agreement nokia make first foreign bank offer financ countri small medium enterpris lr',
#  'provid summari medic equip pipelin product compani develop',
#  'cours talk come new project involv materi handl konecran presid ceo pekka lundmark said ask whether talk relianc industri suppli equip upcom refineri jamnagar',
#  'lidsko pivo invest program forese integr modern product updat transport logist infrastructur develop new market instrument mikshi said',
#  'residentialconstruct particular pick sever market',
#  'ruukki includ djsi world second year run european djsi stoxx third year run',
#  'sale oxygen measur busi strengthen goal focu chosen market segment',
#  'correspond increas 8543250 euro ahlstrom share capit enter trade regist today',
#  'august 2007 latvija finieri order product line new green veneer mill built ukmerg central lithuania',
#  'finnish hous manufactur target strongli grow onefamili hous market russia',
#  'transact alma media rais stake talentum 3065 share 3112 vote right',
#  'aldata said still number oper aspect defin microsoft detail product market initi result agreement avail later date',
#  'alexandria va juli 11 hannu kahonen juuka finland develop ornament design handl fire pit door us patent trademark offic announc',
#  'alexandria va may 16 kenneth bower vista calif develop ornament design handset us patent trademark offic announc',
#  'largest elev market world chines output elev continu rise 262000 unit 2009 5 yronyr',
#  'aspocomp intend set plant manufactur print circuit board invest rs310 crore',
#  'baltic pearl cjsc subsidiari shanghai foreign joint invest compani develop project st petersburg compris million squar meter residenti space two hospit sever school nurseri',
#  'biohit oyj develop manufactur market liquid handl product diagnost test system use research healthcar industri laboratori',
#  'call switchboard directori servic decreas significantli sinc employe uptod contact inform colleagu custom phone place call directli',
#  'cargotec share capit increas total 64046460 euro',
#  'cargotec share capit increas total eur 64299180',
#  'compar ftse 100 index rose 283 point 05 day rel price chang 23',
#  'componenta increas stake turkish steel compani dokta dokumculuk ticaret sanayi 926 pct stake march 2007',
#  'earn per share ep seen eur 056 eur 038',
#  'estonia beer market overal grew three percent last year 130 million liter',
#  'finnish food compani raisio oyj hel raivv said friday wrap divest margarin oper us sector player bung ltd nyse bg eur80m usd119 2',
#  'finnish lift equip maker konecran hel kcr1v said 29 juli 2009 rais stake austrian manipul maker ac konecran 80 bought german sector player knight europ',
#  'finnish paper maker upmkymmen corp monday announc sale wrap unit walki wisa capman invest group move concentr core busi',
#  'follow increas companyeur tm capit total 55 mln romanian lei 198 mln1 56 mln euro',
#  'helsinki afx kci konecran said rais stake mmh hold inc owner usbas morri materi handl 909 pct 745 pct',
#  '2008 gener net sale eur 93 million usd 131',
#  'august latvija finieri order product line new green veneer mill built ukmerg lithuania',
#  'deliv differ user experi enabl us widen market address',
#  'jacob support storengi invest develop storag site sinc 2006 owner engin',
#  'adpnew jun 30 2009 finnish stainless steel maker outokumpu oyj hel out1v said yesterday sign threeyear eur 900 million usd 13 bn revolv credit facil',
#  'increas net sale due acquisit swedish silva produc garden tool boat',
#  'mr ashley deputi execut chairman sport direct sold 43pc stake compani pound 900m time float',
#  'one challeng oil product north sea scale format plug pipelin halt product',
#  'rental build equip account 88 percent oper incom',
#  'ruukki deliveri includ steel structur includ instal krakeroy bascul bridg steel pile bridg foundat',
#  'sanoma continu focu invest digit media strengthen market posit',
#  'stockmann establish 1862 finland becam first foreign compani enter russia retail trade market 1989',
#  'sysopen digia sign agreement main sharehold sentera hold total 7739 share capit vote sentera',
#  'acquisit part suomen helasto strategi expand lukkoexpert secur chain suomen helasto ceo kimmo uusimaki said',
#  'broadbas wig index end thursday session 01 pct 6500334 pt bluechip wig20 113 368715 pt',
#  'busi divest gener consolid net sale eur 60 million annual current 640 employe',
#  'compani gener net sale 600 mln euro 7755 mln annual employ 6000',
# ...
#  'raisio divis record oper profit',
#  'estim 30 pct mobil call made home franc telecom hope 15 pct orang client sign servic end 2008',
#  'broker repeat buy rate base expect current restructur lead clear improv perform europ 2007',
#  'arvo vuorenmaa loviisa plant gener manag said applic new licenc standard procedur quit confid approv grant',
#  'domest busi bestin alreadi close finnish dog owner',
#  'baswar ceo ilkka sihvo comment conjunct interim report whole baswar succeed well second quarter 2007',
#  'cash flow oper activ estim posit',
#  'cision say sale return uk oper profit',
#  'citigroup inc nyse c announc global transact servic gt busi award new mandat finlandbas pohjola bank group',
#  'comptel vendor dynam oper support system oss softwar select orascom telecom oth partner provis activ solut mobil servic',
#  'depart store sale improv 14 eur 10706 mn',
#  'dmasia16 august 2006benefon extend manufactur capabl asmobil _ 2006 digitalmediaasiacom dma ltd',
#  'finland nation carrier finnair plc carri record 85 million passeng 2005 increas 45 percent previou year airlin report tuesday',
#  'finnair plc carri record 88 million passeng 2006 increas 35 percent previou year finnish nation carrier report tuesday',
#  'finnish consult engin group poyri plc omx helsinki poy said wednesday 1 octob award contract tanqia dibba fzc ownerengin wastewat system dibba emir fujairah uae',
#  'finnish financi solut develop baswar corpor omx helsinki bas1v said tuesday 23 septemb deliv complet invoic autom solut larg us engin construct technic servic organ',
#  'finnish handl system compani cargotec oyj hel cgcbv said today eur 13 million usd 166 contract deliv macgregor hatch cover ship order norwegian shipown grieg ship',
#  'finnish oper elisa aker yard sign longterm servic deal elisa deliv necessari voic data servic aker yard finland',
#  'finnish steel maker rautaruukki oyj ruukki said juli 7 2008 90 mln euro 141 mln contract suppli instal steel superstructur partihallsforbindelsen bridg project gothenburg western sweden',
#  'fiskar strong portfolio intern brand includ fiskar iittala gerber silva buster',
#  'telest acquisit mark entri servic busi market long establish signific supplier product',
#  'forestri also higher driven yesterday bullish analyst comment stora enso dagen industri dealer said',
#  'furthermor effici improv measur initi earlier bear fruit ceo jan lang said',
#  'global bank news 28 septemb 2010 tieto corpor pohjola bank pink pojlf cooper swift servic',
#  'hearst abl consolid 20 russian market advertis press purchas',
#  'helsingin uutiset vantaan sanomat lansivayla reach 385000 reader 40 consum greater helsinki region',
#  'helsinki afx metso said upgrad one upmkymmen four paper machin latter mill jaemsaenkoski new coat color suppli system machin process control qualiti measur',
#  'howev simdax remain avail market alreadi approv market authoris submit applic 40 countri orion ad',
#  'howev broker gave outperform recommend stock',
#  'howev total order receiv still last year level',
#  'accord strategi strengthen local presenc establish repres offic south africa octob',
#  'addit lehdentekijat oy start produc new membership magazin viisa raha wise money associ',
#  'futur compani intend look knowhow outsid compani cooper actor sector',
#  'industri invest interest glaston solar energi project',
#  'also potenti client grow environment recycl technolog sector',
#  'lead privat road ambul servic compani finland',
#  'known post bank concept would see fidel bank roll 75 offic ghana post premis provid financi servic peopl',
#  'kone factori locat ayanambakkam suburb west chennai fulli integr facil give capabl address cost',
#  'last year sysopen digia invest ibm product knowhow build portal trade place system success implement custom solut support',
#  'adp news oct 1 2008 finnish consult engin compani poyri oyj omx poy1v said today award eur 52 million usd 74 extens exist consult engin contract venezuel',
#  'adp news oct 31 2008 finnish food compani raisio oyj omx raivv said today net profit jump eur 164 million usd 209 first nine month 2008 eur 11 million period 2',
#  'adp news sep 30 2008 finnish secur privaci softwar solut develop stonesoft oyj said today usd 19 million eur 13 order deliv stoneg network secur product unnam russian te',
#  'meanwhil electrowattekono philippin inc also award threeyear oper mainten om contract fr cement corpor',
#  'meanwhil nokia said abl deliv complet rang servic deploy oper consult integr manag servic result buyout',
#  'metso paper deliveri compris advantag dct 200 tissu machin includ qualiti control distribut control system qcsdc',
#  'net sale 2007 total eur 329 million oper margin 19',
#  'nevertheless fitch note busi fundament three bank current remain sound',
#  'nokia control 50 percent phone sale india africa strong prosit emerg market',
#  'nokia provid indosat turnkey servic includ civil work network plan implement integr wcdma 3ghspa network',
#  'nordic busi report26 june 2006metso corpor win eur50m equip order australia _ 19982006 m2 commun ltd finnish engin technolog group metso corpor said monday 26 june receiv eur50m equip order australia',
#  'sale price sale gain 31 mln euro 45 mln recogn incap earn 2007',
#  'outotec net profit second quarter 2007 jump 168 mln euro 231 mln 46 mln euro 63 mln year ago',
#  'panostaja oyj panostaja board director decid 16 decemb 2010 new longterm incent commit plan member manag team',
#  'pioneer librari system one 127 librari municip art cultur higher educ scienc organ award grant particip big read largest feder read program us histori',
#  'pretax profit jump eur 219 million eur 31 million',
#  'profit ebit 139 compar 131 previousyear period',
#  'raut corpor receiv order worth eur 12 million ooo ilim bratsk dok russia',
#  'recoveri evid liquid handl busi particularli area outsid europ primarili north america asia',
#  'sale improv sek 1553 mn compar sek 1408 mn',
#  'savon koulutuskuntayhtyma finland base compani award contract specialist agricultur forestri machineri',
#  'skf 6 april 2010 alandsbanken given buy recommend swedish industri compani skf ab sto skf b share price target sek150',
#  'soni ericsson nokia domin list bestsel handset five model',
#  'speak justdrink today spokesperson olvi said perform well four countri oper name finland estonia latvia lithuania',
#  'sport equip sale also progress well owe prolong winter season',
#  'stockmann mastercard widen scope cooper estonia latvia',
#  'stora enso record capit gain eur 33 million nonrecur financi item fourth quarter 2006 result',
#  'tele2 affarsvarlden gave buy recommend mobil oper tele2 ab share price target 142 crown 2354 1519 euro',
#  'top consensu forecast earn 021 euro share',
#  'acquisit kaupth sverig bring signific posit nonrecur addit group perform',
#  'acquisit immedi posit impact aspocomp financi result',
#  'amend propos simplifi propos plan increas incent key employe stay compani',
#  'australian compani mirabela nickel award outokumpu technolog contract grind technolog nickel sulfid project bahia state brazil',
#  'broker initi palfing ag konecran oyj buy recommend 51 42 eur price target respect',
#  'buyer aim thu reinforc posit denmark martela group manag director heikki martela said',
#  'compani agre longterm cooper mechanis harvest stora enso eucalyptu plantat southern china',
#  'compani aim maintain trend profit current year',
#  'compani also said poland profit program launch oborniki steel frame sandwich panel plant',
#  'compani establish 3g base station 17000 feet foot mount everest enabl mountain climber 29035foot summit surf internet even send video exploit',
#  'compani also featur ethibel pioneer invest regist includ innovest global 100 list world sustain corpor',
#  'compani goal achiev annual save eur 2 million usd 27 two third realiz 2010',
#  'compani said observ current stabilis price potenti higher price deliveri first quarter 2011',
#  'compani also compens act reserv batch plant',
#  'group also strong global posit fish categori',
#  'group cash flow oper posit',
#  'mill long tradit hold establish posit market',
#  'move aim boost sale costeffici market share finland',
#  'newspap alma media arena partner enter cooper agreement use alma marketplac servic respect region',
#  'origin name componenta _m_l subsidiari finnish componenta group chang _m_l compon compani seen 63 growth q1 2010 comparison q1 2009',
#  'parti also agre option allow uh extens implement later also function human resourc manag',
#  'pilot project prove rifd technolog ideal purpos comment olli saarinen materi handl supervisor yara',
#  'plan facil estim cost around 814 million would largest biodiesel plant world use palm oil certifi roundtabl sustain palm oil rspo',
#  'combin foreign invest creat interest opportun solteq',
#  'done logist largest order norway diversifi group said',
#  'result improv sale figur sweden',
#  'choos baswar tool financi servic seem like natur continu cooper say tommi leskinen financi applic manag nest oil corpor',
#  'agreement geosentr provid gypsiipow hotel inform reserv servic visitor china includ popular citi beij shanghai',
#  'vaisala also said expect net sale eur 2532 million 2010 compar eur 2522 million record 2009',
#  'valid fgvoip client symbian sign repres signific step forward accomplish goal',
#  'wartsila contract octob 2007 plant instal manturovo kostroma region russia 600 km northeast moscow russia',
#  'honor recogn gartner specialist busi process model analysi compani mani largest softwar vendor world',
#  'posit pursu novel clinic candid go forward',
#  'upmkymmen upgrad inlin underperform goldman sach',
#  'consum well receiv pack fresh meat',
#  'demand sport equip good 2005',
#  'last year finnair record 326percent growth asian sector carri 110 million passeng two contin',
#  'addit flight link mumbai helsinki dictat strong traffic demand asia europ',
#  'lower price us competitor show real estat market stabilis return balanc apart acquir fair price eye client',
#  'new structur provid better commun faster decisionmak cost save proha said',
#  'contract demonstr abil appli miner metal technolog adjac industri oil shale process',
#  'pleas deliv baswar invoic autom solut major retail compani us',
#  'tailor solut meet solel technic requir result costeffect manufactur highestqu reflector',
#  'feel quit posit region whole',
#  '21 decemb 2010 finnish industri machineri compani wartsila oyj abp hel wrt1v said yesterday order design liquefi natur ga lng power platform suppli vessel psv norwegian oil servic provid eidesvik offshor asa osl eiof',
#  'finlan list food industri compani hkscan group control compani baltic improv revenu eur 35 mn eur 1604 mn 2010 eur 1569 mn year',
#  'finnish airlin finnair deal uk public sector offici airlin flight london heathrow osaka japan well flight manchest uk helsinki finland',
#  'finnish cargotec award signific order total 292 hiab loader crane bae system us',
#  'finnish cargotec kalmar receiv signific order us depart defens',
#  'finnish outotec award contract suppli new zinc roaster ga clean sulphur acid plant ozk kardzhali zinc smelter bulgaria',
#  'finnish pyri award engin contract cfr nation railway compani romania',
#  'accord report neomarkka kuitu finland custom interest buy compani product restart product',
#  'result distribut compani start distribut addit current product offer shimano reel rod shimano fish tackl product exclus basi',
#  'cargotec germani gmbh award contract stadtverwaltung mainz chassi bodi open procedur',
#  'ceo erkki jaervinen happi compani perform 2010',
#  'deliveri start network readi launch soon',
#  'earn per share quarter also higher yearonyear 033 eur versu 027 market expect 028 eur',
#  'ebitda year 2009 improv eur484m compar eur472m 2008',
#  'estonian telecom compani elisa custom number cross 400000 tallinn oct 22 bn estonian telecommun compani elisa approxim 50000 new client nine month year bring number 401800 end septemb compani said',
#  'exel composit longterm growth prospect remain favour howev',
#  'fi develop cooper keyword advertis microsoft',
#  'finnish construct group lemminkainen oyj hel lem1 said today contract provid technic servic nevski centr shop mall open novemb st petersburg russia',
#  'finnish mobil oper dna function subcontractor maingat respons telecommun connect',
#  'finnish softwar develop baswar oyj said novemb 30 2006 us subsidiari baswar inc order provid softwar contract lifecycl manag unnam us medic technolog compani',
#  'honka subsidiari franc germani also benefit exampl arrang custom event conjunct world cup ski competit',
#  'howev sale volum food industri expect remain rel good level finland scandinavia atria said',
#  'incap lankapaja aim enter actual agreement transfer sheetmet product buyer februari order complet transfer 1 march 2011',
#  'mr kivimeist said john deer former timberjack stand win situat control around 60 estonia forest machineri market',
#  'nokia elisa work togeth bring superior mobil game experi elisa custom',
#  'nordea see return posit growth baltic countri 2011',
#  'oper profit improv 167 eur 77 mn',
#  'oper profit improv 399 eur 180 mn eur12 8 mn',
#  'oper profit improv 440 er 47 mn eur 33 mn 2004',
#  'oper profit improv eur 203 mn eur 114 mn',
#  'outokumpu chief execut juha rantanen express confid china market',
#  'previous compani anticip oper profit improv period',
#  'product situat improv',
#  'rautaruukki said construct group yit award 25 mln eur contract suppli steel structur new bridg span kemijoki river northern finland',
#  'sale came 241 mln eur compar 2114 mln also beat consensu forecast 235 mln eur',
#  'sale vat inclus expand 19 percent 351 million euro',
#  'strong growth continu also china',
#  'synergi benefit start materialis second quarter',
#  'telest sentri 360 form integr partnership sentri advanc 360degre immers camera product line telest enterpris video manag system',
#  'thank multipli effect wagon perform transport much effici say develop manag juha malkia vr cargo',
#  'buy recommend reiter',
#  'aim achiev eur 25 mn yearli save',
#  'borrow happi roadshow paid hit ratio high',
#  'compani make garden tool scissor consum good said earn boost 69 mln eur incom receiv 167 pct sharehold finnish engin group wartsila',
#  'compani anticip turnov whole 2010 surpass previou year eur 671 million',
#  'compani negoti amend financi coven present credit agreement regard situat 30 septemb 2010',
#  'ep improv eur0 38 eur0 27',
#  'expans aim attract new custom finland abroad',
#  'feder secretari transport commun mexico award poyri mexican partner sintra consult contract connect buenavistacuautitlan suburban railway',
#  'financi impact estim annual improv eur2 0 divis result fiscal year 2008',
#  'financi impact estim 15 meur annual improv divis result start fiscal year 2007',
#  'finnish group anticip sale gain eur42m tax expens',
#  'launch plant june went well produc advanc fuel coupl week',
#  'parti agre negoti definit distribut licens agreement end june 2010',
#  'ration oper seek achiev eur 1 million yearli save second quarter current financi year',
#  'sale result gain eur 60 million second quarter 2010 oriolakd support finnish compani strategi focu pharmaceut wholesal retail oper',
#  'stock new machin reason small new order bring work',
#  'third order award outokumpu technolog shalkiya zinc kazakhstan shalkiya zinclead project kazakhstan',
#  'compani abl keep market posit',
#  'acquisit support strategi close custom around world offer equip relat servic',
#  'lay foundat sustain busi develop long term',
#  'turun kaupunkin finland base compani award contract lemminkainen talotekniikka oy electr instal work',
#  'world biggest magazin paper maker said program improv effici includ close sever least competit mill would cover compani oper result annual save euro200 million us 240 million',
#  'moder signific chang result signific 2432 reduct estim cvd risk',
#  'uponor improv perform spite decreas residenti construct us',
#  'inventor issu us patent',
#  'isra cabl network oper hot telecom chosen telest intern technolog group exclus provid fttx equip israel accord telest today',
#  ...]

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True
texts = df['content'].tolist()
labels = df['sentiment'].tolist()

X_train, X_val, y_train, y_val = train_test_split(
    texts, labels,
    test_size=val_size,
    random_state=seed,
    shuffle=is_shuffle)
X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=seed,
    shuffle=is_shuffle)

# %%
class FinancialNews(Dataset):
    def __init__(self, X, y, word_to_idx, max_seq_len, transform=None):
        self.texts = X
        self.labels = y
        self.word_to_idx = word_to_idx
        self.max_seq_len = max_seq_len
        self.transform = transform

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]

        if self.transform:
            text = self.transform(text, self.word_to_idx, self.max_seq_len)
        text = torch.tensor(text)

        return text, label

# %%
max_seq_len = 32

train_dataset = FinancialNews(
    X_train, y_train, word_to_idx, max_seq_len, transform=transform
)

val_dataset = FinancialNews(
    X_val, y_val, word_to_idx, max_seq_len, transform=transform
)

test_dataset = FinancialNews(
    X_test, y_test, word_to_idx, max_seq_len, transform=transform
)

# %%
train_dataset.__len__()
# Out:
# 3391

# %%
train_batch_size = 128
test_batch_size = 8

train_dataloader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=test_batch_size, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# %%
X, y = next(iter(train_dataloader))
y[0]
# Out:
# tensor(0)

# %%
class SentimentClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size, n_layers, n_classes, dropout_prob):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_size, n_layers, batch_first=True)
        self.norm = nn.LayerNorm(hidden_size)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc1 = nn.Linear(hidden_size, 16)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(16, n_classes)

    def forward(self, x):
        x = self.embedding(x)
        x, hn = self.rnn(x)
        x = x[:, -1, :]
        x = self.norm(x)
        x = self.dropout(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %%
vocab_size = len(vocab)
vocab_size
# Out:
# 8908

# %%
n_classes = len(list(classes.keys()))

embedding_dim = 64
hidden_size = 64
n_layers = 2
dropout_prob = 0.2

device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = SentimentClassifier(
    vocab_size=vocab_size,
    embedding_dim=embedding_dim,
    hidden_size=hidden_size,
    n_layers=n_layers,
    n_classes=n_classes,
    dropout_prob=dropout_prob
).to(device)

# %%
lr = 1e-4
epochs = 50

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# # Hourly Temperature Forecasting

# %%
import torch
import torch.nn as nn

seed = 1
torch.manual_seed(seed)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader

# %%
dataset_filepath = 'weatherHistory.csv'
df = pd.read_csv(dataset_filepath)
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 12295  2007-01-05 07:00:00.000 +0100       Overcast        rain
# 12296  2007-01-05 08:00:00.000 +0100  Partly Cloudy        rain
# 12297  2007-01-05 09:00:00.000 +0100          Clear        rain
# 12298  2007-01-05 10:00:00.000 +0100  Partly Cloudy        rain
# 12299  2007-01-05 11:00:00.000 +0100  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# 1             9.355556                  7.227778      0.86            14.2646
# 2             9.377778                  9.377778      0.89             3.9284
# 3             8.288889                  5.944444      0.83            14.1036
# 4             8.755556                  6.977778      0.83            11.0446
# ...                ...                       ...       ...                ...
# 12295         2.466667                 -0.122222      0.99             9.0965
# 12296         2.316667                 -0.377778      0.99             9.3863
# 12297         2.966667                  0.905556      0.99             7.5187
# 12298         5.927778                  3.522222      0.87            11.3344
# 12299         8.772222                  6.500000      0.77            14.3612
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                       251.0          15.8263         0.0
# 1                       259.0          15.8263         0.0
# 2                       204.0          14.9569         0.0
# 3                       269.0          15.8263         0.0
# 4                       259.0          15.8263         0.0
# ...                       ...              ...         ...
# 12295                   202.0           5.5384         0.0
# 12296                   204.0           4.2987         0.0
# 12297                   177.0           4.7495         0.0
# 12298                   243.0           9.6278         0.0
# 12299                   251.0           9.9820         0.0
#
#        Pressure (millibars)                      Daily Summary
# 0                   1015.13  Partly cloudy throughout the day.
# 1                   1015.63  Partly cloudy throughout the day.
# 2                   1015.94  Partly cloudy throughout the day.
# 3                   1016.41  Partly cloudy throughout the day.
# 4                   1016.51  Partly cloudy throughout the day.
# ...                     ...                                ...
# 12295               1018.42         Mostly cloudy until night.
# 12296               1018.41         Mostly cloudy until night.
# 12297               1019.08         Mostly cloudy until night.
# 12298               1019.53         Mostly cloudy until night.
# 12299                 10.00                                NaN
#
# [12300 rows x 12 columns]

# %%
univariate_df = df['Temperature (C)']
univariate_df.index = df['Formatted Date']
univariate_df
# Out:
# Formatted Date
# 2006-04-01 00:00:00.000 +0200    9.472222
# 2006-04-01 01:00:00.000 +0200    9.355556
# 2006-04-01 02:00:00.000 +0200    9.377778
# 2006-04-01 03:00:00.000 +0200    8.288889
# 2006-04-01 04:00:00.000 +0200    8.755556
#                                    ...
# 2007-01-05 07:00:00.000 +0100    2.466667
# 2007-01-05 08:00:00.000 +0100    2.316667
# 2007-01-05 09:00:00.000 +0100    2.966667
# 2007-01-05 10:00:00.000 +0100    5.927778
# 2007-01-05 11:00:00.000 +0100    8.772222
# Name: Temperature (C), Length: 12300, dtype: float64

# %%
input_size = 6
label_size = 1
offset = 1

def slicing_window(df, df_start_idx, df_end_idx, input_size, label_size, offset):
    features = []
    labels = []

    window_size = input_size + offset

    if df_end_idx is None:
        df_end_idx = len(df) - window_size

    for idx in range(df_start_idx, df_end_idx):
        feature_end_idx = idx + input_size
        label_start_idx = idx + window_size - label_size

        feature = df[idx:feature_end_idx]
        label = df[label_start_idx:idx + window_size]

        features.append(feature)
        labels.append(label)

    features = np.expand_dims(np.array(features), -1)
    labels = np.array(labels)

    return features, labels

# %%
dataset_length = len(univariate_df)
train_size = 0.7
val_size = 0.2
train_end_idx = int(train_size * dataset_length)
val_end_idx = int(val_size * dataset_length) + train_end_idx

X_train, y_train = slicing_window(
    univariate_df,
    df_start_idx=0,
    df_end_idx=train_end_idx,
    input_size=input_size,
    label_size=label_size,
    offset=offset
)

X_val, y_val = slicing_window(
    univariate_df,
    df_start_idx=train_end_idx,
    df_end_idx=val_end_idx,
    input_size=input_size,
    label_size=label_size,
    offset=offset
)

X_test, y_test = slicing_window(
    univariate_df,
    df_start_idx=val_end_idx,
    df_end_idx=None,
    input_size=input_size,
    label_size=label_size,
    offset=offset
)

# %%
class WeatherForecast(Dataset):
    def __init__(self, X, y, transform=None):
        self.X = X
        self.y = y
        self.transform = transform

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        X = self.X[idx]
        y = self.y[idx]

        if self.transform:
            X = self.transform(X)

        X = torch.tensor(X, dtype=torch.float32)
        y = torch.tensor(y, dtype=torch.float32)

        return X, y

# %%
train_dataset = WeatherForecast(
    X_train, y_train
)

val_dataset = WeatherForecast(
    X_val, y_val
)

test_dataset = WeatherForecast(
    X_test, y_test
)

train_batch_size = 128
test_batch_size = 8

train_dataloader = DataLoader(
    train_dataset,
    batch_size=train_batch_size,
    shuffle=True
)

val_dataloader = DataLoader(
    val_dataset,
    batch_size=test_batch_size,
    shuffle=False
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=test_batch_size,
    shuffle=False
)

# %%
class WeatherForecastor(nn.Module):
    def __init__(self, embedding_dim, hidden_size, n_layers, dropout_prob):
        super().__init__()
        self.rnn = nn.RNN(embedding_dim, hidden_size, n_layers, batch_first=True)
        self.norm = nn.LayerNorm(hidden_size)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        x, hn = self.rnn(x)
        x = x[:, -1, :]
        x = self.norm(x)
        x = self.dropout(x)
        x = self.fc(x)

        return x

# %%
embedding_dim = 1
hidden_size = 8
n_layers = 3
dropout_prob = 0.2
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = WeatherForecastor(
    embedding_dim=embedding_dim,
    hidden_size=hidden_size,
    n_layers=n_layers,
    dropout_prob=dropout_prob
).to(device)

# %%
lr = 1e-3
epochs = 50

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# # Training

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()
    correct = 0
    total = 0
    losses = []
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            y_pred = model(X)
            loss = criterion(y_pred, y)
            losses.append(loss.item())
            _, predicted = torch.max(y_pred.data, 1)
            total += y.size(0)
            correct += (predicted == y).sum().item()
    loss = sum(losses) / len(losses)
    acc = correct / total
    return loss, acc

# %%
def fit(model, train_dataloader, val_dataloader, criterion, optimizer, device, epochs):
    train_losses, val_losses = [], []
    for epoch in range(epochs):
        model.train()
        batch_train_loss = []
        for idx, (X, y) in enumerate(train_dataloader):
            X, y = X.to(device), y.to(device)

            optimizer.zero_grad()

            y_pred = model(X)

            loss = criterion(y_pred, y)
            loss.backward()
            optimizer.step()

            batch_train_loss.append(loss)
        train_loss = sum(batch_train_loss) / len(batch_train_loss)
        train_losses.append(train_loss)

        val_loss, val_acc = evaluate(model, val_dataloader, criterion, device)
        val_losses.append(val_loss)

        print(f"Epoch: {epoch + 1} | Train loss: {train_loss} | Val loss: {val_loss}")

    return train_losses, val_losses

# %%
train_losses, val_losses = fit(model, train_dataloader, val_dataloader, criterion, optimizer, device, epochs)
# Out:
# Epoch: 1 | Train loss: 0.9961243867874146 | Val loss: 0.9301248060875251
# Epoch: 2 | Train loss: 0.933564305305481 | Val loss: 0.9289460504641298
# Epoch: 3 | Train loss: 0.9350951313972473 | Val loss: 0.9284534830538953
# Epoch: 4 | Train loss: 0.9293509125709534 | Val loss: 0.9284494704887515
# Epoch: 5 | Train loss: 0.933385968208313 | Val loss: 0.9288952130763257
# Epoch: 6 | Train loss: 0.9344950318336487 | Val loss: 0.9289251526848215
# Epoch: 7 | Train loss: 0.9319535493850708 | Val loss: 0.9285263814887063
# Epoch: 8 | Train loss: 0.9265627264976501 | Val loss: 0.9286262759419738
# Epoch: 9 | Train loss: 0.9308967590332031 | Val loss: 0.9286045295293214
# Epoch: 10 | Train loss: 0.9310756921768188 | Val loss: 0.9283192191944748
# Epoch: 11 | Train loss: 0.9282813668251038 | Val loss: 0.928244088028298
# Epoch: 12 | Train loss: 0.9306309223175049 | Val loss: 0.9283115086985416
# Epoch: 13 | Train loss: 0.9279549717903137 | Val loss: 0.9281729322965028
# Epoch: 14 | Train loss: 0.9346045255661011 | Val loss: 0.9280341521638339
# Epoch: 15 | Train loss: 0.928318440914154 | Val loss: 0.9281156439273084
# Epoch: 16 | Train loss: 0.9280628561973572 | Val loss: 0.9278123754946912
# Epoch: 17 | Train loss: 0.9301090240478516 | Val loss: 0.9280457677411251
# Epoch: 18 | Train loss: 0.9305713176727295 | Val loss: 0.9276328946723312
# Epoch: 19 | Train loss: 0.9269790649414062 | Val loss: 0.9282690369692005
# Epoch: 20 | Train loss: 0.9295785427093506 | Val loss: 0.927759685965835
# Epoch: 21 | Train loss: 0.930173397064209 | Val loss: 0.9276667491334384
# Epoch: 22 | Train loss: 0.9270371794700623 | Val loss: 0.9271253469537516
# Epoch: 23 | Train loss: 0.9276199340820312 | Val loss: 0.9271807387226918
# Epoch: 24 | Train loss: 0.9270920157432556 | Val loss: 0.9266853762454674
# Epoch: 25 | Train loss: 0.923995852470398 | Val loss: 0.9261995417172791
# Epoch: 26 | Train loss: 0.9270244836807251 | Val loss: 0.9277247082991679
# Epoch: 27 | Train loss: 0.9264049530029297 | Val loss: 0.9256113371888145
# Epoch: 28 | Train loss: 0.9241463541984558 | Val loss: 0.9248581557977394
# Epoch: 29 | Train loss: 0.9264647960662842 | Val loss: 0.9238837996467215
# Epoch: 30 | Train loss: 0.9250413179397583 | Val loss: 0.9241311498841301
# Epoch: 31 | Train loss: 0.9232780933380127 | Val loss: 0.9226948115669313
# Epoch: 32 | Train loss: 0.9193607568740845 | Val loss: 0.9377464109756908
# Epoch: 33 | Train loss: 0.9152481555938721 | Val loss: 0.9196144374179058
# Epoch: 34 | Train loss: 0.9039440751075745 | Val loss: 0.8950403909214207
# Epoch: 35 | Train loss: 0.8782296776771545 | Val loss: 0.8913275052289493
# Epoch: 36 | Train loss: 0.8787373304367065 | Val loss: 0.9128205663845187
# Epoch: 37 | Train loss: 0.889599621295929 | Val loss: 0.883317835018283
# Epoch: 38 | Train loss: 0.8742018342018127 | Val loss: 0.8823654414688955
# Epoch: 39 | Train loss: 0.8557363152503967 | Val loss: 0.8850976678191639
# Epoch: 40 | Train loss: 0.8507186770439148 | Val loss: 0.8707320748782549
# Epoch: 41 | Train loss: 0.8537912964820862 | Val loss: 0.8837221025443468
# Epoch: 42 | Train loss: 0.8499333262443542 | Val loss: 0.8810835947267345
# Epoch: 43 | Train loss: 0.8306097388267517 | Val loss: 0.8810134026847902
# Epoch: 44 | Train loss: 0.8308306336402893 | Val loss: 0.8661389116381035
# Epoch: 45 | Train loss: 0.8190938234329224 | Val loss: 0.8643387934712113
# Epoch: 46 | Train loss: 0.841973602771759 | Val loss: 0.8783248555464823
# Epoch: 47 | Train loss: 0.8215823173522949 | Val loss: 0.87928257320748
# Epoch: 48 | Train loss: 0.8205656409263611 | Val loss: 0.8652486339455745
# Epoch: 49 | Train loss: 0.8244420289993286 | Val loss: 0.8632888300497024
# Epoch: 50 | Train loss: 0.8099281191825867 | Val loss: 0.8998825757718477

# %%
val_loss, val_acc = evaluate(
    model,
    val_dataloader,
    criterion,
    device
)

test_loss, test_acc = evaluate(
    model,
    test_dataloader,
    criterion,
    device
)

print('Evaluation on val/test dataset')
print('Val accuracy: ', val_loss)
print('Test accuracy: ', test_loss)
# Out:
# Evaluation on val/test dataset
# Val accuracy:  0.8998825757718477
# Test accuracy:  0.8847850399916289
